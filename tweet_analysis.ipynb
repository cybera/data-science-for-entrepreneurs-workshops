# %% [markdown]
# # Text Analysis With Twitter Data
#
# So far in this tutorial series we've discussed at length how to clean and process Twitter data. We've also introduced aspects of Natural Language Processing (NLP) such as word clouds and counting statistics. In this notebook, we're going to construct a topic model using **word vectors**, **word embeddings** and **K-means**. Using these methods, we will show you a few tricks in order to identify groups of tweets defining topics you're interested in. Such a model has applications for the identification of groups of users for targeted advertising,  or as a tool to quickly find relevant tweets to help quantify potential demand for a product/service.
#
# ## Goals
# 1. Turn our tweets into "tweet" vectors.
# 2. Cluster those vectors to define topics.
# 3. Use this model to locate topics relevant to us, and discuss how such a model may be used for market research or advertising.
#
# # Preliminaries
# Before we get started, let's introduce a few concepts and background materials before diving into the materials. For this notebook we have two main concepts to cover: Word vectors, word embeddings. The introduction into k-means clustering will be saved for the relevant section.
#
# ## Word vectors
#
# A word vector is the conversion of a word into a sparse 'one-hot' coded vector. What this means is that each word contained within our tweets is mapped to a unique vector with only a single non-zero element. For example, the word "karate" may appear as
#
# \begin{equation}
# \mbox{Karate} =
# \begin{pmatrix}
# 0 \\
# \vdots \\
# 1 \\
# \vdots \\
# 0
# \end{pmatrix}
# \end{equation}
#
# Where it is represented as a _unique_ and _sparse_ vector that contains a single non-zero entry. The size of each word vector is the same and have size $N$, where $N$ is the number of words in our vocabulary.
#
# ## Sentence Vectors
#
# A sentence vector is simply the word vector representation of sentence or in our case, a tweet. For example, the sentence
# ```
# wax on, wax off
# ```
#
# is the average of the vector sum of our word vectors for each word
# \begin{equation}
# \vec{D}_1 = \frac{1}{3} \left(2\vec{w}_1 + \vec{w}_2 + \vec{w_3}\right)
# \end{equation}
#
# Notice how the vector for `wax` was repeated in this particular example. What this means is that in sentence vectors **punctuation, and the order words appear is not important**. The vector representation of a sentence is the same. For example, the sentences
#
# ```
# Turning words to math? That is lunacy! Why would you do that?
# ```
# and
# ```
# Turning math is lunacy! Why would you do that to words?
# ```
#
# would have an identical _vector_ representation, but are very clearly different sentences.
#
# ## Word Embeddings
#
# On their own, word vectors are often too large and sparse to be particularly useful. More importantly however, because word vectors are linearly independent (no combination of word vectors can be used to make a different word vector) understanding similarities between words (such as synonyms) and the similarities between sentences is impossible. How do we transform these vectors into a form that can be used to understand linguistic similarities?
#
# What we need to do is develop our word embeddings - a new set of vectors which can relate words and sentences based on their similarities. In our case, we're going to use what's known as a "Neural Embedding", or word embeddings that are a result of a neural network trained on text data. In most applications, a fully connected shallow neural network (A neural network with only a single hidden layer) is used, and the resulting parameter weights of the neural network define our _word embeddings_ or a series of **dense** vectors that represent the similarities between words. For our purposes we will be using a set of pre-trained word embeddings available [in this github repository](https://github.com/eyaler/word2vec-slim/blob/master/GoogleNews-vectors-negative300-SLIM.bin.gz). This is a small version of word embeddings resulting from training on Google News, and has a vocabulary of about 300000 words.
#
# Understanding of how these word embeddings is not required. However, for those interested in learning more, feel free to use the drop down menus below in order to understand how the neural network is used to create word embeddings. The first drop down is very high level, and the next two are quite technical.
#
# ---
# <br>
# ## Would you like to know more?
# <details>
# <summary> Click here to learn about the idea of a word embedding </summary>
# <br>
# <h2> Word2Vec Word Embeddings </h2>
#
# In this section we will cover the basics of the model known as `word2vec` using what is known as the Continuous Bag Of Words (CBOW) model. In the CBOW model, our task is to predict "missing" words. For example, if we had the sentence
# ```
# I sure do love learning about word embeddings!
# ```
#
# To train our network, we would remove a single word from the sentence above, say "learning". We would then and predict the word "learning" given an input of the other words in the sentence. Schematically this is represented below
#
# ![scheme](images/wor2vecschem.png)
#
# In this case, we take the input context - the other words in our original sentence, and use those in order to predict the word that we've removed.  As words can exist in multiple contexts (among different sets of input words), this model can discover how different words are related to each other - with enough data we'll understand the "relationships" between words. What is nice about this model is that we have a massive _labeled_ data set for free: all we need to do is grab a bunch of text, and choose which word to move at each step of training!
#
# But wait! At face value, this neural network doesn't sound like it's particularly useful - all its doing is predicting a word based on some words we've given to it as input, we can't even use that outside of the texts we've given it! How is this network useful for understanding language? Well, we won't be using the neural network in the sense that we're using it "online" to create word embeddings. What we'll have from the training process is a set of internal parameters that relate our one-hot encoded vector to _all the other_ one hot encoded vectors. The closer these vectors of internal parameters are together, the more similar words are to each other. In the case of word embeddings, the network we use to create them is _only_ useful in terms of the weights it optimizes - not the output it produces.
#
# What this means is that we will have word embeddings that represent the contextual similarities between words. Instead of using our simple one hot encoded vectors, we will now possess a vector formalism that can be used to understand things such as word similarity, and expand those to things like sentence and document similarity.
#
# ---
#
# ## Would you like to know more?
# <details>
# <summary> Click here to learn more about the neural network and the mathematics </summary>
# <br>
# <h2> Word2vec neural network and mathematics </h2>
#
# The `word2vec` neural network appears most often as the following schematic
#
# > ![word2vec](images/word2vec.png)
# >
# > Image source: https://arxiv.org/pdf/1411.2738.pdf
#
# A brief note on notation: bold quantities will represent both vectors and matrices, and we hope it will be clear given context. In the image above, our input layer takes a word vector $\mathbf{x}$, which is the sentence vector with our target word removed (this vector is referred to as the "context"), and $\mathbf{y}$ is the one-hot word encoded vector that we removed from our sentence vector that we're trying to predict. These vectors are both of length $V$, the number of words in our vocabulary.
#
# We also have $N$ neurons in a hidden layer of $\mathbf{h}$, and two weight matricies $\mathbf{W}$ and $\mathbf{W^\prime}$. Here, $\mathbf{W}$ is a $V \times N$ matrix, and $\mathbf{W^\prime}$ is a $N \times V$ matrix. Notice how the number of hidden neurons defines the size of our hidden parameter matrices.
#
# ## Forward Propagation
#
# Given the schematic above, we see that the values the hidden layer's output is defined as
# $$
# \begin{equation}
# \tag{1}
# \label{eq:h}
# \mathbf{h} = \mathbf{W} \mathbf{x} = \frac{1}{C} \mathbf{W} \cdot \left(\sum_{i=1}^C \mathbf{x}_i \right)
# \end{equation}
# $$
# Where the vector $\mathbf{x}$ in \ref{eq:h} is our sentence vector which is simply the average of all the word vectors that make up the sentence. You may have noticed that in `word2vec` **the hidden layer has no activation function**.
#
# Now, the next step is to compute the **inputs** to each node on the outer layer, which we will define as $u$. For the $j^{th}$ output node we have
# $$
# \begin{equation}
# u_j = {\mathbf{v}^\prime_{\mathbf{W}_j}}^T \cdot \mathbf{h}
# \end{equation}
# $$
# Where ${\mathbf{v}^\prime_{\mathbf{W}_j}}$ is the $j^{th}$ column of the output matrix $\mathbf{W}^\prime$. Finally, we then compute the elements of the output (one-hot encoded) vector $\mathbf{y}$ as a Boltzmann distribution which can be thought of as the 'activation' function of this network.
#
# $$
# \begin{equation}
# \tag{2}
# \label{eq:yi}
# y_j  = p(w_{y_j} | w_1, ..., w_C) = \frac{\exp(u_{y_j})}{\sum_{i=1}^V \exp(u_i) }
# \end{equation}
# $$
#
# Where the subscript $y_j$ means "the index of the $j^{th}$ output of $\mathbf{y}$. Now we have a definition of our word embeddings, namely:
#
# $$
# \begin{equation}
# y(\mbox{word}) = \mbox{argmax} \frac{\exp(u_{y_j})}{\sum_{i=1}^V \exp(u_i) } = u_{y_j = index(\mbox{word})} = {\mathbf{v}^\prime_{\mathbf{W}_{j = index(\mbox{word})}}}^T \cdot \mathbf{h}
# \end{equation}
# $$
#
# Where we have switched to a more obvious notation, but less clear for derivations.
#
# As once our neural network is fully trained, we will have $V$ _word embeddings_ of size $N$, the size of our hidden layer. This is because we will now have a mapping from our one-hot encoded output vectors of a specific word to the specific _word embedding_ $u_j$ from equation \ref{eq:yi}. Indeed, the index $j$ where $\mathbf{y}$ is maximal will represent the column of the matrix $\mathbf{u}$ which represents the embedding of the output word $\mathbf{y}$
#
# ---
#
# <details>
# <summary> Click here to learn about `word2vec back propagation </summary>
# <br>
# <h2> Finding the weights of the neural network  </h2>
#
#
#
# ### Learning $\mathbf{W}$ and $\mathbf{W}^\prime$
# As the training weights define our word embeddings, it is important to discuss how the randomly initialized weights get updated to effectively represent our word embeddings.
#
# ### Updating $\mathbf{W^\prime}$
# As with any neural network, the first step is to define our loss function, in this case we want to maximize the conditional probability (log likelihood) of our output word vector $\mathbf{y}$ given our input context sentence vector $\mathbf{x}$. So, for our first matrix $\mathbf{W^\prime}$
# $$
# \begin{align}
# E & = - \ln p(\mathbf{y_*} | \mathbf{x}) \\
#   & = -\ln \left(  \frac{\exp(u_j)}{\sum_{i=1}^V \exp(u_i) }\right) \\
#   & = -u_* + \ln \sum_{i=1}^V \exp{u_i} \\
#   & = -{\mathbf{v}_{\mathbf{w_O}}}^T \cdot \mathbf{h} + \ln \sum_{i=1}^V \exp({\mathbf{v}_{\mathbf{w}_i}}^T \cdot \mathbf{h})
# \end{align}
# $$
# Where the $*$ subscript on $u_*$ is to indicate the index of the actual output word (our target). Now, let's write out our derivatives explicitly for back propagation. First up,
# $$
# \begin{align}
# \frac{\partial E}{\partial u_j} & = \frac{\partial}{\partial u_j} \left( -u_* + \ln \sum_{i=1}^V \exp{u_i} \right) \\
# & = -\delta_{j,*} + \frac{\partial}{\partial u_j}\ln \sum_{i=1}^V \exp{u_i} \\
# & = -\delta_{j,*} + \frac{1}{\sum_{i=1}^V \exp{u_i} }  \frac{\partial}{\partial u_j}\sum_{i=1}^V \exp{u_i} \\
# & = -\delta_{j,*} + \frac{\exp(u_j)}{\sum_{i=1}^V \exp(u_i) } \\
# & = y_i - \delta_{j,*}
# \end{align}
# $$
# Where $\delta_{j,*}$ is the Kronecker delta defined as
# $$
# \begin{equation}
# \delta_{j, *} =
# \begin{cases}
#         1, &         \text{if } j=*,\\
#         0, &         \text{if } *\neq *.
# \end{cases}
# \end{equation}
# $$
#
# Now that we have the derivative of our loss function with respect to the input to the $j^{th}$ node of our output layer $u_j$, we can also calculate the partial derivative with respect to the output weight $w^\prime_{i,j}$ via the chain rule
#
# \begin{align}
# \frac{\partial E}{\partial w^\prime_{i,j}} & =\frac{\partial E}{\partial u_j} \frac{\partial u_j}{\partial w^\prime_{i,j}} \\
# & = (y_j - \delta_{j,*} ) \frac{\partial u_j}{\partial w^\prime_{i,j}} \\
# & = (y_j - \delta_{j,*} ) \cdot \frac{\partial}{\partial w^\prime_{i,j}}\left( {\mathbf{v}^\prime_{\mathbf{W}_j}}^T \cdot \mathbf{h} \right) \\
# & = (y_j - \delta_{j,*} ) \cdot \frac{\partial}{\partial w^\prime_{i,j}}\left( \sum_k w_{k,j} h_k \right) \\
# & = (y_j - \delta_{j,*} ) \cdot h_i
# \end{align}
#
# Fantastic! Now we can define an update equation using gradient decent with learning rate $0 < \eta < 1 $ as
#
# \begin{equation}
# w_{i,j}^{\prime (new)} = w_{i,j}^{\prime (old)} - \eta (y_j - \delta_{j,*} ) \cdot h_i
# \end{equation}
#
#
# or, in vector notation
# \begin{equation}
# \mathbf{v}_{\mathbf{w}_j}^{\prime(new)} =\mathbf{v}_{\mathbf{w}_j}^{\prime(old)} - \eta (y_j - \delta_{j,*} ) \cdot \mathbf{h}
# \end{equation}
#
# Where recall that $\mathbf{v}_{\mathbf{w}_j}^{\prime}$ is the $j^{th}$ vector of our weight matrix $\mathbf{W}^\prime$
#
# ### Updating $\mathbf{W}$
#
# We also have a similar equation for the input weights. Our first derivative will be taken with respect to an arbitrary hidden node $h_i$
# $$
# \begin{align}
# \frac{\partial E}{\partial h_i} &= \sum_{j=1}^V \frac{\partial E}{\partial u_j} \cdot \frac{\partial u_j}{\partial h_i} \\
# & = \sum_{j=1}^V (y_j - \delta_{j, *} )\cdot \frac{\partial}{\partial h_i} \left( \sum_j w^\prime_{i,j} h_j \right) \\
# & = \sum_{j=1}^V (y_j - \delta_{j, *}) \cdot w^\prime_{i,j}
# \end{align}
# $$
# Where the sum is a result of the hidden layer being fully connected. The next derivative is the derivative of our loss function with respect to an arbitrary weight $w_{k,i}$
# $$
# \begin{align}
# \frac{\partial E}{\partial w_{k,i} } & = \frac{\partial E}{\partial h_i} \cdot \frac{\partial h_i}{\partial w_{k,i}} \\
# & = \sum_{j=1}^V (y_j - \delta_{j, *} )\cdot w^\prime_{i,j} \cdot \frac{\partial}{\partial w_{k,i}}\left[ \frac{1}{C} \mathbf{W} \cdot \left(\sum_{l=1}^C \mathbf{x}_l \right) \right]\\
# & = \frac{1}{C} \left( \mathbf{x} \cdot \sum_{j=1}^V (y_j - \delta_{j, *} )\right) \cdot \frac{1}{C} \cdot x_k \\
# & \Rightarrow \frac{1}{C} (\mathbf{x} \cdot EH)
# \end{align}
# $$
# Where
# $$
# \begin{equation}
# EH = \frac{1}{C} \left( \sum_{j=1}^V (y_j - \delta_{j, *} )\right)
# \end{equation}
# $$
# and $\mathbf{x}$ becomes a vector after summation over $k$. In this case, the final gradient update equation for the input weight is
# $$
# \begin{equation}
# {\mathbf{v}_{\mathbf{w_{I,c}}}^{\prime}}^{(new)} = {\mathbf{v}_{\mathbf{w_{I,c}}}^{\prime}}^{(old)} - \frac{\eta}{C} EH
# \end{equation}
# $$

# %% [markdown]
# ## Downloading Tweets and Word Embeddings
#
# In the cell below we're downloading our cleaned tweets once again from the Rapid Access Cloud and putting them into a data frame. We also define our `model`, which is our pre-determined word embeddings that we can use to understand word similarity mathematically.
#
# **Note** This first cell may take a few moments to run as it's downloading ~ a 300 mb file to your hub account.

# %%
import gensim
import urllib.request
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np 
from numpy.linalg import norm

# download word vectors
model_url = "https://swift-yeg.cloud.cybera.ca:8080/v1/AUTH_233e84cd313945c992b4b585f7b9125d/geeky-summit/GoogleNews-vectors-negative300-SLIM.bin"
model_file = 'GoogleNews-vectors-negative300-SLIM.bin'
urllib.request.urlretrieve(model_url, model_file)

# Load pretrained model 
model = gensim.models.KeyedVectors.load_word2vec_format(model_file, binary=True)

# download tweets
target_url="https://swift-yeg.cloud.cybera.ca:8080/v1/AUTH_233e84cd313945c992b4b585f7b9125d/geeky-summit/alberta_tweets_cleaned.csv"
file_name="alberta_tweets_cleaned.csv"
urllib.request.urlretrieve(target_url, file_name)

df = pd.read_csv(file_name,parse_dates=['created_at_date']) 
# Convert to mountain standard time 
df.created_at_date= df.created_at_date.dt.tz_localize('UTC').dt.tz_convert('MST')
df.head(2)
# Out:
#             created_at_date   hashtags_string     user_string  \
# 0 2018-12-18 10:23:54-07:00     xmas nicelist  CallawayGolfEU
# 1 2018-12-18 10:24:19-07:00  highschooldesign
#
#        user_location  longitude  latitude          name  screen_name  \
# 0                NaN        NaN       NaN   jeff ullock   JeffUllock
# 1  Kitscoty, Alberta        NaN       NaN  Jackie Bouck  JackieBouck
#
#                                       extended_tweet  \
# 0  @CallawayGolfEU The crows nest hands down! #xm...
# 1  Does anyone know of any high schools that have...
#
#                               extended_tweet_cleaned
# 0                     The crows nest hands down!
# 1  Does anyone know of any high schools that have...

# %% [markdown]
# ## Word Embedding Test Drive
#
# Before we dive into the analysis, let's take a look at these "word embeddings" that we've now discussed at length. In this case, let's look at the embedding for the word "chocolate"

# %%
# Remove the 'len' function and its enclosing parenthesis to look at the vector 
# directly if you're interested 
len(model.wv['chocolate'])
# Out:
# 300

# %% [markdown]
# What we see here is that the word embedding is a 300 dimensional vector. This means two things:
# 1. The neural network these embeddings were taken from had a hidden layer of size 300
# 2. All words that this network was trained on (in this case approximately 300000) have been mapped down do 300 dimensional vectors, rather than their original sparse 300000 dimensional vectors. What a space savings!
#
# Now that we have smaller vectors what can we do with them? As these are now "dense" vectors, we can start to do more exciting vector things with them. For example, we can calculate how "close" these vectors are to each other.  The idea being that the closer two word embeddings are, the more similar in meaning the words they represent are. In this case, vector similarity is calculated using the cosine distance between two vectors $\mathbf{A}$ and $\mathbf{B}$ is defined as
#
# \begin{equation}
# \mbox{similarity} = \frac{\mathbf{A} \cdot \mathbf{B}}{||\mathbf{A}|| ||\mathbf{B}||} = \frac{\mathbf{A} \cdot \mathbf{B}}{\sqrt{\sum_i A_i^2} \sqrt{\sum_i B_i^2} } = \left[-1, 1\right]
# \end{equation}
#
# where this is simply the dot product of the normalized vectors. A similarity, often called a cosine distance, can take values between -1 and 1. Values of -1 imply that the vectors are anti-parallel, and in the context of word embeddings these words can be considered to be "opposite". A similarity of 0 implies the vectors are orthogonal, meaning that these words are not similar. Finally, a similarity score of 1 implies they're the same vector, or the same word. **The closer to one the similarity between two word embeddings are, the more similar the words are**.
#
# Let's take that for a spin, first, lets see the most similar words to "chocolate"

# %%
#here we're getting the 10 most similar words to the word "chocolate"
model.most_similar(positive=['chocolate'])
# Out:
# [('chocolates', 0.7569215893745422),
#  ('Chocolate', 0.7080809473991394),
#  ('caramel', 0.673201322555542),
#  ('caramels', 0.6604536175727844),
#  ('candy', 0.6375688910484314),
#  ('candies', 0.6303936839103699),
#  ('nougat', 0.6247628927230835),
#  ('macaroons', 0.6229639649391174),
#  ('Chocolates', 0.6201929450035095),
#  ('choco', 0.612962543964386)]

# %% [markdown]
# In the output above, what see is the word as the first output, and the cosine similarity as the number reported. Feel free to try other words in the above example.
#
# We can also add and subtract these word embeddings to discover how words may be related in more complex ways. For example we can return results like
#
# > Man is to King as woman is to ____
#
# Where we would fill in the word "Queen" by hand. In terms of vectors, this is done as
#
# $$ \mathbf{V}(queen) = \mathbf{V}(king) - \mathbf{V}(man) + \mathbf{V}(woman) $$
#
#
# Which can be done using our model below

# %%
model.most_similar(positive = ['king','woman'], negative=['man'])
# Out:
# [('queen', 0.7118192911148071),
#  ('monarch', 0.6189675331115723),
#  ('princess', 0.5902431011199951),
#  ('prince', 0.5377322435379028),
#  ('kings', 0.5236844420433044),
#  ('queens', 0.518113374710083),
#  ('sultan', 0.5098593235015869),
#  ('monarchy', 0.5087411999702454),
#  ('throne', 0.5005807876586914),
#  ('royal', 0.4938204884529114)]

# %% [markdown]
# Which, is exciting in the sense that now **anything we can do to a vector, we can now do with language**.
#
# ## Preparing Tweets
#
# Our goal now is to create "tweet" vectors by adding up all the word vectors in our tweets. Mathematically we're after something of the form
# \begin{equation}
# \mathbf{V}_{tweet} = \frac{1}{N}\sum_{word}^N \mathbf{V}_{word}
# \end{equation}
# where $N$ is the number of words in our tweet.
#
# But first - we have to do what we always do: clean our tweets even more. The first step, as we've seen before is to remove stop words and turn our tweets into tokens. In this case, the reason we're removing stop words is because they don't add anything "meaningful" to our sentences, and if we keep them in we'll accidentally make tweets look more similar to each other than they are because they're cluttered with filler language! This is done below

# %%
import nltk
stop_words = nltk.corpus.stopwords.words('english')
stop_words.append('amp')
print(stop_words[1:10])
stop_words = set(stop_words)
# Out:
# ['me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
subset = df.copy()

# tokenization and punctuation removal
def sent_to_words(row):
    sentence = row.extended_tweet_cleaned
    return(gensim.utils.simple_preprocess(sentence,min_len=3))  

# Create a new "tokens" colmn with our sent_to_words function
subset['tokens'] = subset.apply(sent_to_words, axis=1)

# Wrapper function to clean all the text at once 
def tokens_to_lda(row):
    data_token = row.tokens
    tokens = [token for token in data_token if token not in stop_words]
    return tokens

## Now we create a 'lemma' column for our super cleaned data!
subset['lemma'] = subset.apply(tokens_to_lda, axis=1)

# # We are also removing all data where the tweet is less than four words long. 
subset = subset[subset['lemma'].apply(lambda x: len(x) > 3)]

print("Total Tweets to analyze after cleaning: ", len(subset))
subset.head(3)
# Out:
# Total Tweets to analyze after cleaning:  23380
#             created_at_date   hashtags_string user_string      user_location  \
# 1 2018-12-18 10:24:19-07:00  highschooldesign              Kitscoty, Alberta
# 2 2018-12-18 10:24:30-07:00                      miss9afi    Alberta, Canada
# 3 2018-12-18 10:24:44-07:00                     ABLiberal   Calgary, Alberta
#
#    longitude  latitude                 name  screen_name  \
# 1        NaN       NaN         Jackie Bouck  JackieBouck
# 2        NaN       NaN  Faiz Ali Qureshi 🇨🇦    FKamranAB
# 3        NaN       NaN     Irwin Singh Brar      roti888
#
#                                       extended_tweet  \
# 1  Does anyone know of any high schools that have...
# 2  @miss9afi That's blasphemy law you can say  it...
# 3  Albertans voted for @ABLiberal in 1993-2012 th...
#
#                               extended_tweet_cleaned  \
# 1  Does anyone know of any high schools that have...
# 2    That's blasphemy law you can say  it's like ...
# 3  Albertans voted for   in 1993-2012 they were o...
#
#                                               tokens  \
# 1  [does, anyone, know, any, high, schools, that,...
# 2  [that, blasphemy, law, you, can, say, like, ho...
# 3  [albertans, voted, for, they, were, official, ...
#
#                                                lemma
# 1         [anyone, know, high, schools, pods, grade]
# 2  [blasphemy, law, say, like, holocaust, law, we...
# 3  [albertans, voted, official, opposition, nearl...

# %% [markdown]
# ## Finding "Tweet Vectors"
#
# To find tweet vectors, we simply take the average of all the word vectors in our cleaned and processed tweets. This is done below.

# %%
# Here we are making a list of all the words we have vectors for 
vocab = model.vocab.keys()

def tweet_vectorizer(tweet):
    vector = [0 for i in range(300)]
    count = 0
    # Here we build our tweet vectors 
    for w in tweet:
        if w in vocab:
            count += 1
            vector = vector + model[w] 
    if len(tweet) != 0:
        # Divide by the norm here so we can be lazy with a matrix multiplication later. 
        vector = np.array(vector) / count
        vector = vector/norm(vector)
        return list(vector)
    else:
        # If no words in the tweet are in the model, we set it to zero
        # to ensure it will be opposite to all other word embeddings. 
        return [0 for i in range(300)]

# Actually call the function 
subset['vect'] = subset['lemma'].apply(tweet_vectorizer)
subset = subset.reset_index(drop=True)

# Here we truncate our set
subset = subset[0:20000]
subset.tail(2)
# Out:
#                 created_at_date hashtags_string user_string  user_location  \
# 19998 2018-12-25 21:13:13-07:00            shpk              Sherwood Park
# 19999 2018-12-25 21:14:03-07:00                              HoneyMoon Ave
#
#        longitude  latitude           name screen_name  \
# 19998        NaN       NaN  Ian McCormack   ian_mccor
# 19999        NaN       NaN             aj    jayonchy
#
#                                           extended_tweet  \
# 19998  To all those who represent me and my #shpk fam...
# 19999                  My cousin got a tiktok account 💀
#
#                                   extended_tweet_cleaned  \
# 19998  To all those who represent me and my   family,...
# 19999                  My cousin got a tiktok account 💀
#
#                                                   tokens  \
# 19998  [all, those, who, represent, and, family, than...
# 19999                     [cousin, got, tiktok, account]
#
#                                                    lemma  \
# 19998  [represent, family, thank, public, service, al...
# 19999                     [cousin, got, tiktok, account]
#
#                                                     vect
# 19998  [-0.041741188413688554, 0.03636025888633516, 0...
# 19999  [0.0038887161563631663, -0.007502408045238537,...

# %% [markdown]
# ## Finding Similar Tweets

# %% [markdown]
# We've now created our own "tweet" vectors using our pre-trained model, let's take a look and see how well it worked! First, try out the code below. You will have to write a little code first however! But, note in the cell below
#
# \begin{equation}
# A =
# \begin{pmatrix}
# \begin{bmatrix}
# & & V_{\mbox{tweet } 1} & & &
# \end{bmatrix} \\
#  \begin{matrix}
#  & & \dots & & &
# \end{matrix} \\
#  \begin{matrix}
#  & & \dots & & &
# \end{matrix} \\
# \begin{bmatrix}
# & & V_{\mbox{tweet } N} & & &
# \end{bmatrix}
# \end{pmatrix}
# \end{equation}
#
#
# Is the matrix of all our tweet vectors, where each row is an individual tweet vector. Keep in mind we've also **already normalized all our tweet vectors**. So you don't have to worry about normalizing things again when you're calculating your similarity scores.

# %%
# Create the matrix A
A = np.array(subset['vect'].tolist())
print(A.shape)

# index of the tweet we're interested in, feel free to change this. 
# Note, that it's currently set to the last tweet, so your choices must be > 19999
interest = 19999
# this is the tweet vector at the index we've decided to use 
target = np.array(subset['vect'].iloc[interest])

# I will remove this to be an exersize YOUR CODE HERE
myvals = A @ target 

max_index = myvals.argsort()[-5:][::-1]
# if you're interested in the _least_ similar tweets, try changing thngs with this
# min_index = np.argpartition(myvals, 5)[:5]


print("="*90)
print("Note: The first most similar tweet will be the tweet itself")
print("Tweet we're looking for similarities to:\n\n",subset['extended_tweet_cleaned'].iloc[interest])
print("="*90)
print()
for index in max_index:
    print(subset['extended_tweet_cleaned'].iloc[index],"||" ,"index =", index,  "similarity score=", myvals[index])
    print()
# Out:
# (20000, 300)
# ==========================================================================================
# Note: The first most similar tweet will be the tweet itself
# Tweet we're looking for similarities to:
#
#  My cousin got a tiktok account 💀
# ==========================================================================================
#
# I'm at Chinook Centre -   in Calgary, Alberta  || index = 17915 similarity score= 0.06225133813128733
#
# Downtown Calgary @ Calgary, Alberta  || index = 19962 similarity score= 0.030486150259774525
#
# Downtown Dubai! @ Windermere, Edmonton  || index = 1131 similarity score= 0.05675171358963514
#
# I'm at Calgary International Airport (YYC) -   in Calgary, AB  || index = 15805 similarity score= 0.06247596862576314
#
# 🛫🇰🇼 (@ Calgary International Airport (YYC) -   in Calgary, AB)  || index = 11725 similarity score= 0.06247596862576314

# %% [markdown]
# Feel free to search for different tweets which are similar. There will be some cases where it works quite well, and some cases where... well it probably didn't do the best job. Unfortunately, that's just the nature of twitter - this model can't account for things like spelling mistakes, emojis, and the typical non-sense that one might expect from within 20000 tweets. But, there will certainly be cases where you may be surprised at how well this method works from nothing but a simple matrix-vector dot product!
#
# # K-means clustering as a topic model
#
# As we mentioned earlier, as our tweets are now vectors, we are able to do "vector things" with them. One such "vector thing" is the ability to cluster vectors together based on similarity. This means that we can group similar vectors together and create multiple groups of similar vectors, in our case, tweets that contain similar language used. Each of these groups may represent a topic, and we can use these topics to better understand what people are discussing in these tweets - and if we can use that to better understand something of interest to us.
#
# ## K-means
#
# K-means is an algorithm that will group similar vectors (data) around $k$ centers, where the number of centers $k$ is determined in advance. Essentially, K-means will sort our vectors based on similarity, and group similar tweets together for us. K-means clustering is deceptively simple and can be described as the following iterative steps
#
# 1. Initialize by defining $k$ centroids _randomly_. With our tweets, these centroids will be 300 dimensional vectors.
# 2. Repeat the following until changes between iterations are minimal
#       - Assign each data point (our tweet vectors) to the centroid to which it is closest to.
#       - Recalculate the positions of the centers based on the mean of the data points that were assigned to it.
#
# If you're interested in learning more about K-means clustering, expand the drop down below, however an intimate understanding of the algorithm is not required to complete the rest of this tutorial.
#
# ---
# <details>
# <summary> Click here to learn more about the k-means algorithm </summary>
# <br>
#
# ## The K-means clustering algorithm
# In this case, we define a set of centers
# \begin{equation}
# means =\left\{\mu_i\right\} |_{i=0}^k
# \end{equation}
# where $k>1$, the number of centers you'd like to look for (and in our case, the number of topics).
#
# Once we've decided on the number of topics, the objective of k-means is to find
#
# \begin{equation}
# \tag{3}
# \label{eq:kmean}
# f(\mathbf{\mu};\mathbf{x}) =\min \sum_{j \in k} \sum_{i \in S_j} ||x_i - \mu_j||^2
# \end{equation}
#
# where the sets $S_j$ are the sets of points which are closest to center $\mu_j$. In order to find the appropriate means $\mu_j$ an iterative procedure is used. Specifically, we have the following algorithm.
#
# ---
# **initialize** $\mu_1, ..., \mu_k \rightarrow$ our randomly chosen centers <br>
#
# **While** objective function \ref{eq:kmean} improves **do**<br>
# &nbsp;&nbsp;&nbsp;&nbsp; **Assign** each $\mathbf{x}_i$ to a set $S_1,.., S_k$ based on euclidean distance from each center $\mu_j$: <br>
#   &nbsp;&nbsp;&nbsp;&nbsp; **for** $i$ **in range(N)** $\leftarrow$ $N =$Number of data points <br>
#   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $j =  \mbox{argmin} ||x_i - \mu_k||^2$ <br>
#   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; add $\mathbf{x}_j$ to $S_j$ <br>
#   &nbsp;&nbsp;&nbsp;&nbsp; **end for** <br>
#   &nbsp;&nbsp;&nbsp;&nbsp; **for** $j = 1,...,k$: <br>
#   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $\mu_j$ =$ \frac{1}{\mbox{len}(S_j)}\sum_{i \in S_j} x_i$ $\leftarrow$ calculate new centers<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;**end for** <br>
# **end while**
#
#
#
# Once that algorithm has converged, we will have a set of $k$ optimize means, and each data point will be assigned to the mean that is closest to it.

# %% [markdown]
# ## Choosing $k$, the number of clusters
#
# As the number of clusters $k$ is required for our algorithm, how do we decide on how many clusters we should have? Well, this is a case where Data Science becomes more art than science. In this case, we will opt for an "elbow plot", or a plot where we calculate a metric for how well our topic model performs, and the "ideal" number of topics is where further iterations of the model stop improving. This is done in the cell block below. However, it can take a moment to run, so it is currently commented out. If you'd like to generate your own figure, certainly feel free but note it may take 5-10 minutes to calculate.

# %%
# from IPython.display import clear_output
# inert = []
# for i in range(2,200):
#     clear_output()
#     print(i)
#     # here we're simply calculating more clusters each iteration. 
#     intertia_test = MiniBatchKMeans(init='k-means++', n_clusters=i+1, random_state=5, init_size=3*i)
#     # This is where we fit our data to our k-means topics 
#     intertia_test.fit(A)
#     # WE also save what's known as the model inertia - which is related to how far away each data point 
#     # is from a given topic. A smaller inertia indicates a "better" model. 
#     inert.append(intertia_test.inertia_)

# plt.figure(figsize=(12,8))   
# plt.xlabel("Number of clusters", size = 16)
# plt.ylabel("Momentum (smaller is better)", size=16)
# plt.plot(inert)
# plt.show()

# %% [markdown]
# If you run the code cell above, you should get a plot which looks like the one below
#
# > ![elbow plot](inertia.png)
# > Figure: This figure is the "elbow" plot which will aide us in choosing the best number of topics

# %% [markdown]
# From the figure above, we see that the "momentum" of our plot, or the objective function, gets smaller and smaller as we add more and more topics. In this case, the "elbow" is at approximately 77 topics, and for many applications, that may be the number of topics you wish to choose. However, for our analysis we're going to choose the full 200 as we have reason to believe that out of 20000 tweets, we probably have more than 77 topics at a given time. This is done below, however, feel free to experiment with the `n_clusters` parameter in the cell below and experiment with different topic models. Each model typically only takes a second or two to complete.

# %%
from sklearn.cluster import MiniBatchKMeans
# Define the k-means model
kmeans_model = MiniBatchKMeans(init='k-means++', n_clusters=200, random_state=5)
# Pass it the matrix A, or all out tweets!
kmeans_model.fit(A)
cluster_labels  = kmeans_model.labels_

# %% [markdown]
# ## Testing The Topic Model
#
# Now that we've created a topic model, it might be nice to test how well it did! In this case, let's see how k-means clustered tweets from an obvious source. We're lucky in that there is a twitter account `@311Calgary` which tweets out things like road reports, dead animal pick ups, traffic light fixes and so forth. The idea here however is that many of these tweets are very formulaic, and if our topic model performed admirably, these tweets should be clustered well

# %%
tweets311 =subset[subset.screen_name == '311calgary'].index.tolist()
places=[]
for labels in tweets311:
    # Here cluster_labels[labels] returns the topic that each tweet has been assigned to 
    places.append(cluster_labels[labels])
# set removes duplicates
print(set(places))
# Out:
# {1, 194, 66, 36, 169, 111, 48, 144, 50, 146, 23, 184, 81, 119, 24, 112, 189, 158, 31}

# %% [markdown]
# Where the numbers above are all the topics where the tweets from `@311calgary` got sorted. Explore each topic and see how well you think our model did. Some topcis (such as 48, the default below) seem to be very well sorted. However, as you explore see if you can find some exceptions - but also read further to see if you can understand _why_ something may have been grouped "incorrectly".

# %%
# Change cluster_labels == NUM to view different topics 
itemindex = np.where(cluster_labels== 48)[0]
itemindex
c=0
for i in itemindex:
    c +=1 
    print(subset['extended_tweet_cleaned'].iloc[i])
    print()
print(c)
# Out:
# Opened Streetlight - Not Working Properly request via iphone at 500 RIVERFRONT AV SE  Single light out, this light is not mapped on the street ap website ( so i can't report it on there, pe...
#
# Opened Streetlight - Not Working Properly request via iphone at 254 RIVER ROCK PL SE  Street light not working.
#
# Opened Streetlight - Not Working Properly request via iphone at 771 130 AV SW  5-6 streetlights not working.
#
# Opened Streetlight - Not Working Properly request via iphone at 498 25 AV SE  Several street lights have been out for months at the intersection of 3rd st and 25th ave se. please fix as it's quite dangerous during the morning...
#
# Opened Streetlight - Not Working Properly request via iphone at 178 BRIDLECREST BV SW  .
#
# Closed Streetlight - Not Working Properly request at 500 RIVERFRONT AV SE  Added to streetlight application.
#
# Closed Streetlight - Not Working Properly request at 254 RIVER ROCK PL SE  Added to streetlight application.
#
# Closed Streetlight - Not Working Properly request at 771 130 AV SW  Already reported on streetlight app - no further action.
#
# Closed Streetlight - Not Working Properly request at 498 25 AV SE  Already reported on streetlight app - no further action.
#
# Closed Streetlight - Not Working Properly request at 178 BRIDLECREST BV SW  Already reported on streetlight app - no further action.
#
# Opened Streetlight - Not Working Properly request via web at 440 Scenic View Bay NW Scenic Acres  Street lamp has not been working for several weeks. this photo was taken on november 22nd.
#
# Closed Streetlight - Not Working Properly request at 440 Scenic View Bay NW Scenic Acres  Already reported on streetlight app - no further action.
#
# Opened Streetlight - Not Working Properly request via iphone at 24 AERO DR NE  Lights not coming on at all in this area.
#
# Opened Streetlight - Not Working Properly request via iphone at 11409 ROCKYVALLEY DR NW  Street light closest to pedestrian crosswalk not working.
#
# Opened Streetlight - Not Working Properly request via iphone at 2440 DOUGLASDALE BV SE  Burned out light.
#
# Opened Streetlight - Not Working Properly request via iphone at 1220 CENTRE ST NE  Streetlights out.
#
# Closed Streetlight - Not Working Properly request at 24 AERO DR NE  Already reported on streetlight app - no further action.
#
# Closed Streetlight - Not Working Properly request at 11409 ROCKYVALLEY DR NW  Added to streetlight application.
#
# Closed Streetlight - Not Working Properly request at 1220 CENTRE ST NE  Added to streetlight application.
#
# Closed Streetlight - Not Working Properly request at 2440 DOUGLASDALE BV SE  Already reported on streetlight app - no further action.
#
# Who needs a tree when lights will work!
#
# Closed Streetlight - Not Working Properly request at 525 56 Ave SW Windsor Park  Already reported on streetlight app - no further action.
#
# Opened Streetlight - Not Working Properly request via iphone at 2024 47 ST SE  Street light out.
#
# Opened Streetlight - Not Working Properly request via iphone at 3 ATLANTA CR SE  Street light out.
#
# Opened Report Concern Not Listed request via android at 220 11 AV SE  Bright lights shining directly into residential windows from construction across the alley.
#
# Closed Streetlight - Not Working Properly request at 4421 78 AV SE  Added to streetlight application.
#
# Opened Traffic or Pedestrian Light Repair request via iphone at 10202 TUSCANY HILLS WY NW  Lights not working.
#
# Opened Streetlight - Not Working Properly request via android at 5980 MADIGAN DR NE  String of streetlights out on very busy madigan drive, again, continuing problem for a week now.
#
# Closed Streetlight - Not Working Properly request at 5980 MADIGAN DR NE  Already reported on streetlight app - no further action. wr id 20861.
#
# Opened Streetlight - Not Working Properly request via iphone at 56 REDSTONE LI NE  The street light is not working. it's in front of 45 redstone link ne.
#
# Opened Streetlight - Not Working Properly request via iphone at 187 MASTERS AV SE  Burnt out street light. area is very dark at night.
#
# Closed Streetlight - Not Working Properly request at 187 MASTERS AV SE  Added to streetlight application.
#
# Opened Streetlight - Not Working Properly request via iphone at 8597 BOW TR SW  Street light is strobe light.
#
# Opened Streetlight - Not Working Properly request via web at 888 Sherwood Blvd NW Simons Valley  Streetlight burnt out in front off 888 sherwood blvd.
#
# Closed Streetlight - Not Working Properly request at 8597 BOW TR SW  Already reported on streetlight app - no further action. wr id 20638.
#
# Closed Streetlight - Not Working Properly request at 888 Sherwood Blvd NW Simons Valley  Added to streetlight application. wr_id=21021.
#
# Opened Streetlight - Not Working Properly request via iphone at 33 CHAPMAN ME SE  Street light not working in our cup de sac.
#
# Closed Streetlight - Not Working Properly request at 33 CHAPMAN ME SE  Added to streetlight application. wr_id=21022.
#
# Opened Streetlight - Not Working Properly request via android at 137 CORAL REEF MR NE  Street lights on too early.
#
# Closed Streetlight - Not Working Properly request at 137 CORAL REEF MR NE  Added to streetlight application. added to streetlight app wr_id=21032 - mc dec 22, 2018.
#
# Opened Streetlight - Not Working Properly request via iphone at 1120 VARSITY ESTATES DR NW  Street lights not on.
#
# Closed Streetlight - Not Working Properly request at 1120 VARSITY ESTATES DR NW  Already reported on streetlight app - no further action. wr id 20598.
#
# Opened Streetlight - Not Working Properly request via iphone at 4 MILLPARK RD SW  Street light is making very loud noise and light is flashing.
#
# Closed Streetlight - Not Working Properly request at 4 MILLPARK RD SW  Added to streetlight application.
#
# Opened Streetlight - Not Working Properly request via android at 1817 CROWCHILD TR NW  Pedestrian light on the stairs up the bridge at mcmahon stadium is out.
#
# Closed Streetlight - Not Working Properly request at 1817 CROWCHILD TR NW  Added to streetlight application. added to streetlight app wr_id=21041 - mc dec 23, 2018.
#
# Opened Streetlight - Not Working Properly request via iphone at 328 PUMP HILL CR SW  Street light burnt out.
#
# Opened Streetlight - Not Working Properly request via iphone at 131 PUMP HILL CR SW  Street light not working.
#
# Closed Streetlight - Not Working Properly request at 131 PUMP HILL CR SW  Added to streetlight application.
#
# Closed Streetlight - Not Working Properly request at 328 PUMP HILL CR SW  Added to streetlight application.
#
# 50

# %% [markdown]
# However, if you view the topics that our 311 Calgary tweets got placed into - you'll notice that different kinds of reports got placed in their own topic automatically such as street light reports (topic 48) and dead animal pickup (topic 50). This was all done automatically - we did nothing to ensure that this happened. This is simply a result of the similar language used in each of the `311Calgary` tweets being very similar, which makes them easy to cluster.
#
# # Finding Topics You Care About
#
# From the above, you've probably noticed that we just have a bunch of numbers representing topics - we still have no idea what those topics actually are! Unfortunately that's not something we can get away from, in any form of clustering, it is still up to us, a human, to decide what the topic is actually about. However, we can "cheat" a little and add data to our data set which we feel represents a topic we're interested in, and use that to find a topic we care about.
#
#
# What we're going to do next is create some "fake" data and see if we can find some topics about food and sports. How we're going to do this is insert our own tweets into the data, and re-run the topic model with these new tweets. Then, we'll simply see where our fake tweets ended up!
#
# Before we get into it, remember that we're essentially adding custom word vectors - and the word vectors don't care about things like word order, grammar, or filler words. We essentially just need to do a **key word search**. Let's take a look at how that's done below.

# %%
# Make a new data frame to not mess anything else up 
subset_with_discovery = df.copy()

# here are the sentences we're adding 
sentences = [
    "I am hungry what should I eat in town? looking for recommendations",
    "I could really go for brunch right now",
    "I sure could go for a meal. what's the best pizza in town?",
    "Come down to for the best food in town!",
    "breakfast is the most important meal of the day",
    "what should I eat for dinner? i've got a craving for junk food",
    "i am lazy today, what should i order for dinner to feed myself",
    "thinking about ordering in some food for dinner",
    "hockey garbage bad goal",
    "sports! games! winning! boy do I enjoy these atheletes",
]

# Insert a fake user so they're easy to find like the 311calgary tweets 
user = 'fake_tweets_for_analysis'

# Need to fill in the other data to the table, here we're just entering nothing 
add = {
    'created_at_date':[np.nan for i in range(len(sentences))],
    'hashtags_string':[np.nan for i in range(len(sentences))],
    'user_string':[np.nan for i in range(len(sentences))],
    'user_location':[np.nan for i in range(len(sentences))],
    'longitude':[np.nan for i in range(len(sentences))],
    'latitude':[np.nan for i in range(len(sentences))],
    'name':[np.nan for i in range(len(sentences))],
    'screen_name':[user for i in range(len(sentences))],
    'extended_tweet':[np.nan for i in range(len(sentences))],
    'extended_tweet_cleaned':[sentences[i] for i in range(len(sentences))]
}
    
add = pd.DataFrame.from_dict(add)

# We also need to treat this data just like the original data! Nothing new here 
add['tokens'] = add.apply(sent_to_words, axis=1)
add['lemma'] = add.apply(tokens_to_lda, axis=1)

add['vect'] = add['lemma'].apply(tweet_vectorizer)
new_subset = pd.concat([subset, add]).reset_index(drop=True)

print("Total Tweets to analyze after cleaning: ", len(new_subset))
# This is to just look at our inserted fake tweets 
new_subset.tail(5)
# Out:
# Total Tweets to analyze after cleaning:  20010
#       created_at_date hashtags_string user_string user_location  longitude  \
# 20005             NaN             NaN         NaN           NaN        NaN
# 20006             NaN             NaN         NaN           NaN        NaN
# 20007             NaN             NaN         NaN           NaN        NaN
# 20008             NaN             NaN         NaN           NaN        NaN
# 20009             NaN             NaN         NaN           NaN        NaN
#
#        latitude name               screen_name extended_tweet  \
# 20005       NaN  NaN  fake_tweets_for_analysis            NaN
# 20006       NaN  NaN  fake_tweets_for_analysis            NaN
# 20007       NaN  NaN  fake_tweets_for_analysis            NaN
# 20008       NaN  NaN  fake_tweets_for_analysis            NaN
# 20009       NaN  NaN  fake_tweets_for_analysis            NaN
#
#                                   extended_tweet_cleaned  \
# 20005  what should I eat for dinner? i've got a cravi...
# 20006  i am lazy today, what should i order for dinne...
# 20007    thinking about ordering in some food for dinner
# 20008                            hockey garbage bad goal
# 20009  sports! games! winning! boy do I enjoy these a...
#
#                                                   tokens  \
# 20005  [what, should, eat, for, dinner, got, craving,...
# 20006  [lazy, today, what, should, order, for, dinner...
# 20007  [thinking, about, ordering, some, food, for, d...
# 20008                       [hockey, garbage, bad, goal]
# 20009  [sports, games, winning, boy, enjoy, these, at...
#
#                                                  lemma  \
# 20005          [eat, dinner, got, craving, junk, food]
# 20006               [lazy, today, order, dinner, feed]
# 20007               [thinking, ordering, food, dinner]
# 20008                     [hockey, garbage, bad, goal]
# 20009  [sports, games, winning, boy, enjoy, atheletes]
#
#                                                     vect
# 20005  [-0.025321025580665246, 0.016945259725013113, ...
# 20006  [-0.00010902933489062215, 0.04867578789929024,...
# 20007  [-0.01738429638295659, 0.05729033811958152, -0...
# 20008  [-0.04039893203205397, 0.08731015589402055, 0....
# 20009  [0.02700282281033466, 0.0659146339314114, 0.00...

# %% [markdown]
# Great! We've created our fake data and inserted it into our set, let's make a new kmeans model and see where those ended up!

# %%
A = np.array(new_subset['vect'].tolist())
print(A.shape)
kmeans_model = MiniBatchKMeans(init='k-means++', n_clusters=200, random_state=5)
kmeans_model.fit(A)
cluster_labels  = kmeans_model.labels_
# Out:
# (20010, 300)

# %% [markdown]
# Same code as our 311Calgary tweets, lets' see where our nefarious fake tweets have landed in the topic model, and judge for ourselves how well they worked.

# %%
places=[]
infultrators = new_subset[new_subset.screen_name == user].index.tolist()
for labels in infultrators:
    places.append(cluster_labels[labels])
print("Our fake tweets of 'known' topic gave ended up in the following topics:\n", places)
# Out:
# Our fake tweets of 'known' topic gave ended up in the following topics:
#  [73, 73, 73, 73, 113, 73, 113, 113, 185, 8]

# %% [markdown]
# # Let's look at where our "infiltration" tweets ended up
#
# Let's start with topic `8`, which is our sports topic and see how well it did. This is done below

# %%
itemindex = np.where(cluster_labels== 8)[0]
itemindex
c=0
for i in itemindex:
    c +=1 
    print(new_subset['extended_tweet'].iloc[i])
    print()
print(c)
# Out:
# @KdotAnderson There are no easy outs in the NHL. Any team can beat anyone on any night. The only stat that matters is winning and The Flames are doing exactly that.
#
# @ReidWilkins Did Chia tell Hitch to play his boy Caggiula higher in the lineup?
#
# Since Whitecourt Wolverines have the best fans, Christmas is coming early tonight at the Scott Safety Center! During tonight's game against the Pontiacs, we have some Christmas giveaways for some lucky fans attending the game and some fun intermission events! Don't miss out!
#
# @RickInBuffalo @jimrome @MikeinBuffalo_ @Kevinschmidle @LabattRu @ErbieStyle @RainbowAirInc @haic_style @KyleinGB @DaveInTheBuff @Malkin14 Throwback jersey is strong. War you dressing up as Phil Housley for tonight's game
#
# @LeroyEdwards8 With the momentum that's in the team at the moment "Definitely"👌👍
#
# @TSNRyanRishaug Referring culture in hockey is awful and a blight on the game. But, it will never change, so just learn to live with it or watch a different sport.
#
# You know your #flossing game is strong when the @fcsfearless4s write the code for it with @microbit_edu. #CBESTEM #FCSinspired #FCSturns25 @KidsCoding @principalfero
#
# After 2 tough games against Major League teams, we got our first win in @MyCWSA 8v8 over @BlizzardSoccer_ United. Goals from Halle (4), Abbey, Madi, Rachel. Paige with the clean sheet. Next game Jan 6. #HappyHolidays 🎄 📸: @RealBBM
#
# @Fan960Steinberg Yep. Keep playing him. He’s been dead solid.
#
# I’ve got Dodgeball game face on! Tomorrow my colleagues &amp; I are going to “Grab Life by the Ball” 😆 we have a lot of pent up energy to release right @RayBilodeau ? #DontMessWithMarketing
#
# @jimrome the only reason to expand the college football playoffs is to ensure that The Ohio State isnt left out
#
# @DarrenWHaynes @TheAthleticCGY @jtbourne Thursday nights game is going to be a battle for sure. Good teams should bury bad teams and that's what the Flames have been doing
#
#
# So to pull it back together:  #1) Ref is atrocious in a game against Edm 2 nights ago. #2) Ref is called out. #3) Ref calls a mysterious goal (???) for the opposing team #4) And then a match penalty on a guy who didn't miss a shift?  NHL should make an example of him.
#
# Gord Miller obviously doesn’t watch any Oilers games...
#
# I saw a girl wearing an Oilers-Pronger jersey when I walked in tonight, pretty sure this game is all her fault.
#
# @shaky_ds @TSNRyanRishaug And 2 head coaches and 6 assistant coaches have not been able to fix it
#
# @GMillerTSN Sorry, Gord, I guess you haven’t watched any Oilers game this year. It is really that bad. If you think we want to watch the hooking and holding more than skill, we can watch 80’s games.🙄
#
# @NHLFlames Suck it up buttercup and move on! Can’t win em all. (Actually you could win em all, but then you’d be playing even more ridiculous than you are right now 🤪🤪🤪) Thanks for the game! Next one Thursday!!! 👍👍
#
# @NHL is the greatest game on earth IMO.
#
# T shirt toss at the #oilers game is in my section and the shirts are just hitting the fans in the back of the head as they are leaving   #talbot
#
# @EclecticBlogs @J_TheCynic @dstaples @NHL He let in one bad goal, arguably. Whatever. The team plays different in front of the #1 goalie.
#
# My face actually got soooo warm after that frigging goal. Im doje watching the game for now lol
#
# @DKingBH This was the classic "win one you shouldn't at the end of the streak" game (and yes I know they lost in Van but you know what I mean).  Calling that a goal and confirming it?  And it's a guy who reffed Sunday?  Woof.
#
# Bad/Controversial call against the Oilers or not, Oilers effort level was sub par and did not deserve to be in the game at all. Draisaitl imo had a terrible game, has to move his feet...embarrassing against the Blues.
#
# Well there was a couple Oilers skating with pianos on there back...and reffing was very questionable...again!
#
# Great night playing reindeer games at @whiskdessertco
#
# This has to be the worst reffed NHL game I’ve seen this year. Just can’t figure out the ref’s reasoning. #Canucks
#
# @oml_mike @Robin_Brownlee boys are looking tired...8 games 14 nights? Hopefully come out little more motivated Sat
#
# The #Oilers game got so bad that my Dad started cheering for Manchester United....
#
# If all pro sports Officials in all leagues crapped 💩 out would come the @NHL Officials on &amp; off the ice. The game is becoming unwatchable #FixIt
#
# @globemartyk @EdmontonOilers @NHL Should've beaten? Canucks have beaten teams far better than the Oilers this season &amp; can't think of a side who's underachieved more than the Blues. Let's not get carried away.
#
# The Oilers just lost to a team who is trying to trade their whole roster lmaaaoooo
#
# Im surprised how well my cardio is when I play ball 😅
#
# Yes #xbox @xbox knows my #2018 #yearinreview @minecraft @MCCommunityTeam  @chipster70 @WatchMCBC  This is the #game I play! or do I live?
#
# Credit???? 2 points is huge right now, “felt”???? Fack that the game isn’t reffed in feelings it’s reffed in facts!
#
# Many hockey faces of Jaxon 1) Final tourny game 2) Game Face 3) Mom face 4) New lax stick face  #sportlife  #sewardsofinstagram  @WarriorHockey warriorlax @…
#
# Maybe he’s great to have in the room and on the bench, but at this point Lucic is providing absolutely nothing to the actual game being played on the ice. Any one of the forwards who were HS tonight would be a better option.
#
# Top Golf Earl Grey mattseifgolf allanloosh kellstr22 #golf @ Earl Grey Golf Club
#
# What a joke, could of been a controlled game if refs kicked him out as warranted.
#
# @bulletkenny @Xbox @FortniteGame @XboxSupport Im calling it but its true i got to the end  whhyyyyyy Fortnite cant be my 2nd most played game. #TheYearIsNotOverYet ;) whyyyyyyyyy. lol
#
# Studio 99 is pretty damn awesome. Game over but arena is open for fans!
#
# Can we teach the NFL replacement refs to skate, better than the horse shit we are seeing now!
#
# @jeonqhcn If Woozi were King  of Chess                I would be honoured to be his Prawn 🦐                                                   We would picnic with His Awesomeness                                          And play Croquet on the Great Lawn!
#
# Still to come on the @DonWheatonGM #PostGameShow with @duckmillard we'll bring you our #FakeLockerRoomSound and @JasonGregor joins us after 11.  Text us your #hashtag of the game to win #OilKings tix.  Are #Oilers fans rioting yet?
#
# It’ll hurt certain fans out there because most Jets fan have this arrogance about them for no real discernible reason other than having had a couple decent seasons.  And a so-so playoffs where they underachieved.
#
# @thatgirlondeck focus on hockey for a bit think about holiday season NFL playoffs and super bowl  college bball playoffs/March madness Spring training  Heaven
#
# How did the ref behind the play see that?
#
# @CCRHL game report free for [0] game(s)
#
# Just when the boys’ team doing good this year and have a great chance to make provincials this year, the girls team decides to ruin it... basketball season is over... 💔
#
# I scored a hat trick in the #NHLHatTrickChallenge daily game. So did 23% of @NHL fans who played.
#
# ok never playing smash online late at night because everybody is a literal try hard like calm tf down you're playing online not the last round of a melee tournament
#
# I scored a hat trick in the #NHLHatTrickChallenge daily game. So did 23% of @NHL fans who played.
#
# @Bob_Stauffer Whether 0/3 on the PK or 0/5 on the PP. The result is almost never in your favor in todays NHL. These games now are won or lost on special teams.
#
# @Oil_Drop 0/5 on the powerplay. How many games does any NHL team win in todays NHL when they go o for on the powerplay? Less than 25% Id guess.
#
# The @canmoreeagles have 6 players with 30+ points and 3 other players are on the verge of reaching that 30 pt mark. Only 1 team has as many players with 30+ points and it’s Brooks. I guess a pretty deep team we have this year. #depth #AJHL
#
# @FriedgeHNIC As a lifelong Flyers fan , also Flames season tix gooder, I'm very pleasantly optimistic about Hart...he is a future star...just can't rush such a young talent that plays tender... I think Fletcher knows that
#
# @FriedgeHNIC ..the team needs a huge shakeup..only a few untouchables...Claude,Coutts,Ghost...lotsa vets can go .... Simmonds, JVR, Vorechek all look like they are playing Sunday morning Shiny most nights....get young prospects or picks now
#
# @Hatshep12 @geology24_7 Sidney Crosby: “I would never let my children play hockey. The risk of getting drafted by Edmonton is too high”  via @TheBeaverton
#
# I’m currently playing the 7th Player on  Come and join me!
#
# @Kaisonious @ReidWilkins @lowemustgo Oiler fans complaining about officiating on Twitter? That’s a new one
#
# “I need you” “you’re differerent” we playin that game now huh
#
# @KurtLeavins Fair but it is how every towering goalie, and even most of the non-towering guys, play.
#
# U18 Ace Of Spades Red Embracing The Christmas Season At Practice! . . . . .  #acevolleyballclub #aceofspades #yyc #acefamily #christmas #team #christmasspirit @ Ace Volleyball Club
#
# @KMooreCJOB @NHLFlames @DallasStars @KellyHrudey @Sportsnet Thanks Kelly! I learned a lot from you early in my AHL days. Thanks for taking a young, green play-by-play guy under your wing!
#
# The NBA is a travelling league. Also palm the ball as much as you want.
#
#
# @NHLPlayerSafety @EdmontonOilers Why aren’t NHL Officials fair in their judgements. They are partial towards other teams that try to harm Connor Mcdavid.  AND Refs turn blind eye to all this. This sort of behavior takes the fun out of watching the game!
#
# @hollaugo Yea, I think Man U made one of the biggest mistake by replacing #MOU with Ole Gunnar Solskjaer. Its obvious the management does not have a vision for the club. I will watch your championship matches.
#
# Best of luck to all Calgary teams &amp; all #DMSG goalies ! Will be watching &amp; posting videos &amp; pix. #MakingSavesattheMACs @MacsTournament #YYC
#
# Nick Nurse trying not to get fined in his post game tonight:
#
# Just saw a video from Spawn Wave showing that @souljaboy's console runs PS1 games better than the #PlaystationClassic 😂. Shame on you @Sony @AskPlayStation!
#
# Come Spin to Win with us on     Saturday, December 22nd.   You have the chance to win a FREE DETAIL &amp; Tons of other prizes!
#
# Here is the Lineup for the Saints tonight in Sherwood Park! #AJHL
#
# Oh man, I’m so not ready to have children be emotional game content yet. But this story is brilliant.
#
# Yah this is huge for me too. DMs who start the game with a round of player introductions make my game so much better. #DnD
#
# @Safimod @CliffyD Yeah Saturday seems to be common for a few teams (haven’t looked at all teams schedules just overall look).
#
# @NotUrAvgHoodrat Philly special next game?
#
# @XavierWoodsPhD @MmmGorgeous @UpUpDwnDwn If this series ends before Prince Pretty brings Creed down to zero fans, I'll cry.
#
# @jtbourne That’s a fantastic contract for the 2nd best player in the game, holy smokes.
#
# @Oil_Drop @SanderEDM @SportsnetSpec First time suspended and Dunn should have gotten the same.  2 games is fair imo
#
# Huge strides in the art form of rap coming tonight, can't wait to hear these MC's spit game changing bars
#
# It sure is frustrating to lose a match, rematch and then stomp all over them because you figured it out, only for them to ragequit and deny you any kind of win or even playing out the set past one. Like why even play ranked? TheRedDeath22 you are a coward &gt;:(
#
# Started watching the soccer doc "Sunderland 'til I Die" yesterday.  So many parallels with the Oil: glorious history, flash stadium, northern working class town, passionate &amp; loyal fans. And on and especially off the field, a bumbling club that just can't get out of its own way.
#
# @tigers This is my 360° photo from game 2 of the 2017 season. It’s on my Facebook page...
#
# Match 30 in the #DarkBeerDonnybrook is a good ol’ fashioned #3way as we decide our finalists for the best #AlbertaBeer Dark Beer. @BandedPeak_Brew , @outcast_brewing and @annexales go to war! Who will it be?
#
# @Legopolis THIS IS ADORABLE!  I have only this moment become aware of this game.
#
# Feeling personally attacked.... Alexa play Usher - My Boo
#
# 9pm start for #Habs game in Arizona tonight .. should be a fun game .. I got the #Habs winning tonight .. easy.  #Habs top9 forwards are too fast for Coyotes to keep up with.  #goHabsGo
#
# Doesn't matter your team the Oilers plate is the better looking plate.
#
# @stuftotalkabout @KuntryKane205 @26Int_Hit The Lions coaching staff though... Gonna be a sick defense.
#
# If you wanna see a good Rocky stand in in pro wrestling, watch @mikeywhipwreck_'s early matches in ECW. He's the ultimate underdog
#
# @stuftotalkabout @KuntryKane205 @26Int_Hit Players wanna play for good coaches. Look at all the free agents.. BC is gonna bring in more talent.
#
#
# Playing the Advent board games and the Tales if a Fourth Grade Nothing games we created. Our buddies rally enjoyed playing with us. @stdominic_ccsd
#
# @HyperX hosting a tourney. @LVBAGFN is randomly in the lobby. Dumpsters everyone. ggs. HyperX y’all better make a team and make him the captain ;)
#
# @Murray86 @BWildeGlobal The other element to consider is: was he cheating earlier in his OHL career? Has he improved his two-way game, face-offs, etc, etc.
#
# Dragon Quest XI S got a trailer for Nintendo Switch at Jump Festa. All the in game cut scenes look the same as PS4. No actual game play. Will have Japanese voice acting added into this version.
#
# Actually, Stephen Hawking is probably a better basketball player than Trump is a deal maker.
#
# Is it possible to manage a @EASPORTS_MUT  team, play @NeverwinterGame AND @TESOnline ??
#
# @Tkachukyou Try growing up in awe of @TheoFleury14 as he absolutely crushed the national league
#
# I’m currently playing the 7th Player on  Come and join me!
#
# @ClayTravis See Colin Kaepernick.  Also NFL players have the worst contracts, from the perspective of injury impact in major league sports.
#
# Kovacic is that player that will drop minimum a 7/10 every game. Absolutely love the guy, He’s actually so consistent. Just wish he had goals to his game, he’d be such a complete midfielder.
#
# @DynastyRich @DynastyNerds U trust Allen is gonna go whole game?
#
# Best player of 2018? I don't see Messi in this video so it can't be
#
# Our Ugly Christmas Sweater Contest is now over and the winner is ... mandiecane_ ! 🏆 It was a close one, but her Rudolph riding ensemble took the lead! Thank you to our amazing team who…
#
# We have a few more spots in our Personalized Group Coaching Program. How good do you want to play in 2019?
#
# @ToeiAnimation This game is going to fucking suck and I can't believe you're going to murder FighterZ so that this game gets all the spotlight. #FuckToei
#
# @ManCity Manner of defeat is d issue rather than d defeat itself&amp; not learning lessons from d past (2+ seasons). Defensive teams will always play a certain way, it is for d coach to adapt&amp; if not working, change tactics/players! City still look shaking at set pieces&amp;quick counter attacks.
#
# Incredible play started by Messi and finished by Dembele. 1-0 Barca!
#
# @worm_tracker You boys going to the game today?
#
# @Jareddutoit @commie22 We’re going to @MillStreetYYC at 12:30 with James Love, @pingzinger and @patjwilmot, then heading to the game from there.
#
# @TaintlessRed @Hammoudeh201 That's b'cuz JK has been rotating his players frequently to give everyone a rest as to make them not get burnt out. We have a lot more games to play in many competitions. JK knows his stuff &amp; knows when to take a player out &amp; replace him with a game changer like "BIG SHAQ" M8👌👍
#
# Lingard makes it 5-1 United An ass kicking in Ole Gunnar Solskjaer's first match as coach
#
# Liverpudlians From All over The World Sends A "BIG" Christmas Thank You To Roy Hodgson&amp;His Team For Their Scintillating 3-2 victory over   Manchester City Today at the Etihad Stadium leaving Liverpool atop of the Premier League Tables&amp;Moving Forward To Capturing The League Title
#
# Solskjaer: “I arrived on Wednesday night and only had Thursday and Friday with the players. Wayne Rooney text me and gave me some advice - so it must be down to him! He told me to make them play football, enjoy themselves and be Manchester United.” #MUFC #ManUtd
#
# I'm playing Grumpy Cat's WORST-GAME-EVER! Download  #GrumpyCat #WorstGameEver
#
# The @RMRaidersAAA Alumni Game will be live streamed at  2pm start
#
#
# Flames game with the Fam on Saturday.  Repping some third jerseys and an original retro, Dylan was working the press level repping ol blasty and missed the photo. @NHLFlames #Flames #NHL #GoFlamesGo
#
# That  game yesterday still has me perturbed.  You go toe to toe with the best team in the league one night and totally shit the bed a couple of night's later against one of the worst.  Elite teams don't do that.  They win when they're supposed to.  Mike Smith cannot be trusted
#
# Playing around with #Nodejs and the Twitter API.  This is fun!!!  #programming #api
#
# That  game yesterday still has me perturbed.  You go toe to toe with the best team in the league one night and totally shit the bed a couple of night's later against one of the worst.  Elite teams don't do that.  They win when they're supposed to.  Mike Smith cannot be trusted
#
# I’m currently playing the 7th Player on  Come and join me!
#
# Always the fantasy football bridesmaid.  5 2nd place finishes. :/  Projected to finish 2, 3, 3  Fudgecycles
#
# RIP to your championship hopes and dreams, Gurley owners.
#
# I would argue Rookie League. Like the imports we had in Sask baseball when I was a kid in the 60s!
#
# This play calling is straight outta 2004.  I am doomed to cheer for incompetent and archaic teams. Sp frustrating. Might have to give up sports.  Or complaining on Twitter.
#
# I just dont understand how TB thinks they can grind out games on the ground with people. The D cant stop anything. Score and score often.  You were winning when you were throwing 50 passes a game.
#
# @bookofloob @CRoatis The ‘88 and ‘89 Flames teams were a league wide powerhouse, and some how Ramage + a backup goalie tipped the scale to winning the cup.  Maybe, but it’s a bit rich.
#
# Aren’t these the same guys who said our players were smoking crack?
#
# @Royal_BLT Smith played like crap.  All 3 goals were stoppable. The Blues didn't play great.  Not by any stretch.  The Flames were just that bad on top of getting no saves.
#
# @SeanPullins I don’t know what it’d be like to actually win a playoff game.    Maybe first full December game I’ve watched in 3 years
#
# Finally Xmas break, meaningful NFL games and Fantasy Football Playoffs, love it @slats91hogs @steve_tansowny
#
# Got the nephews right now, they playing Megaman and Sonic
#
# @rrodrigues_06 "elite" teams, teams considered to be contenders, don't do that.  Happens to often.  Edmonton, Dallas, St Louis just in the last little bit.  6pts left on the table.  No good.
#
# Team Rogue’s hearts went out to this little ringette player, raising $900 as a team. Love our ringette community
#
# @FlamesNation Are they flames reading their own press clippings? Why aren’t they showing up for games they “should win”?
#
# Man these Niners games have been fun to watch lately
#
# @allinkid I went up against Rodgers, CJA and Robby Anderson today. You will not be seeing a screenshot of that matchup.
#
# Antonio Brown makes me miss playing football
#
# Congrats 🎊 Bantam 3, another big win for Mavericks #MavsYYC
#
# @MaxColella1 @NikkF07 Steelers come back w/ FG ties the game.
#
# hate both teams but wow what a game!!
#
# Great catch by Brown .. Wow .. Rothlesburger has all the time in the world to make a throw... fun game :) @NikkF07
#
# Steelers game possibly gonna be decided by their FG kicker ..  LiveStream of @NikkF07 right now :)
#
# Football is fun to watch this season!! #bears #BearDown
#
# @NikkF07 .. watched the #Browns game today .. he's only getting better :)
#
# @BleacherReport Man, tough luck. Guy rips the ball out of his hands while he's on top of another player...but those PI calls??
#
# @errolmorris .. he changed the game for documentaries IMO.
#
# Teams gotta stop running in jumbo
#
# Team Canada v. Team Finland WJHC pre-tournament match about to start. My favourite hockey of the season.
#
# Cowboys prob to host Seahawks in playoffs even though they beat us and will most likely will have a better record. :) :) #nfl #howbouthemcowboys! #CowboysNation
#
# @TheRealBlake88 That’s true for current soccer players as well 😉😉😉
#
# Back to back tournament gold over 8 days for the @MavsHockeyYYC Midget 1 boys. Amazing group of young men, love being a part of their development. Ready for the regular season! Merry Christmas everyone!
#
# @Sinnd8 Is this how folks whose teams haven’t had playoff success act?
#
# Saints cannot risk injuries next week in a meaningless game. Brees, Kamara, Ingram, Thomas, Armstead, Ramczyk should all sit.
#
# I’m currently playing the 7th Player on  Come and join me!
#
# @albertarabbit @MikeMcPickles @trapdinawrpool Tom was playing to the right. He was still a liberal.
#
# A giant pond hockey tournament is coming to Chestermere Lake this week and I would imagine it’s the rink of @DarrenDreger’s ODR dreams. #yyc  @WCPondHockey
#
# @davisfranco Dude I was legit going to write #4 would be getting to the semis of both my fantasy football leagues and a finals in one in just my second year of playing 😏🏈
#
# There’s this Chinese game called Go, played all over Asia and one of the hardest games in the world. The game has an infinite amount of moves (think checkmate moves in chess x 1 million). That’s how these East Asians think. These guys plan 2-3 decades ahead at a time.
#
# @barryt30 @mamoose2001 @Ken_Meen @grumpy_grannie @fordnation @liberal_party In the long runs demand will fall. The USA isn't the only player fighting for market share. All oil producers are playing the game. Those with the highest costs, like AB, will be the first ones crushed by the game.
#
# @onzoBall @mosesmaingi16m @brfootball So when Moaradona carried Argentina on his back in 1986 &amp; won.There was no stars on that team except Diego..So the rest of the team was the weak link in your opinion...Yet they won the WC
#
# @RayDiBrango @antwanstaley Yeah imagine all the playoff teams right now lost their starting QB for 5 games? Losing Brady, Brees, Wilson Big Ben? Interesting to see where those teams would be. Not comparing the players just the situation.
#
# All I want for XMas is some decent owners for our pro-sports teams ..  #goRichPeopleGo #MTL
#
# @DruhFarrell @wordpressdotcom Ever tried to play croquet on a meadow?
#
# @ChanceDafraGGer @HoodieFN I sponsor a player who is amazing at the game but isn’t getting anywhere cause of the whole clout ego problem
#
# @CThelasco @c_monds Cam been playing hurt for a min 😂
#
# Finalizing our complete hockey coverage through New Nine, we will showcase all the bad ass ladies in 🇨🇦 that play the game!   📸@StFXAthletics @rdcqueenshockey @SAIT_Trojans   #newnine #newninehockey #womenshockey #womensicehockey #womenshockeylife
#
# BREAKING: On tonight’s #RAW, @VinceMcMahon officially confirmed the #WWE Women’s Tag Team Championships!
#
# BREAKING: On tonight’s #RAW, @VinceMcMahon officially confirmed the #WWE Women’s Tag Team Championships!
#
# Why are the #Raiders even trying to win this game? #MNF
#
# @WWE @RondaRousey What a great match @NatbyNature and @RondaRousey thank you both for a great match no thanks to @BrockLesnar never around WWE Women Championship is now the top title on RAW not the Universal Championship
#
# Bruce had about 8 of them in a home game vs Ben Bennet and Duke, as the old ball coach kept calling plays with only a tight end to block him ....
#
# This is what winning a NFL Fantasy Football title looks like.  My boy Mitch and the angels took me to the promise land! @nflnetwork @NFL @Michael_Fabiano @ScottHanson #FantasyFootballChampion  @ESPNFantasy
#
# @itmeJP We go to a locked room and then come home and eat Chinese food and play board games.
#
# @ltarsenal Only worried that Torreira picks up another yellow card, thereby missing the Liverpool match
#
# @_PeteSmith_ I was doubtful.  But Higgins is a legit outside receiver in this league
#
# @TeamCanada1972 @CanadiensMTL @DetroitRedWings @v_couture The Pocket Rocket had the C on for their 1973 Cup + Dryden didn’t start wearing that mask until 73/74 season. The pic is in the Forum, 2nd period I think?. Look how small Richard looks! No advertising on boards! Game has changed so much.
#
# @ronakpw Sun and Ultra Sun are the ONLY games I haven’t beat yet. I played Red/Blue/Yellow, Silver, Sapphire, and Leafgreen all back to back in preparation for Let’s Go because I haven’t played the Gen 1 games before and wanted to see the differences between generations
#
# @Sid_Seixeiro But let's enjoy watching the Knicks play lol 😪
#
# @BSTeGz Oh, you kids matching xmasish pj’s.    Have you converted her yet (to Eagles and Kings fandom)?
#
# Merry Christmas to all our followers from the team at Priddis Greens! We wish you all the best and look forward to seeing you in 2019. @ Priddis Greens Golf &amp; Country Club
#
# @Interruptweets y’all being played at my gym , big time !!
#
# Came across this video again. My man Iggy ❤️❤️❤️❤️❤️ favourite player of all time
#
# Hooked up my nephews switch, they playing kirby
#
# @jhump_13 This game cost me 💵 and my parlay! Christmas is ruined!
#
# Checking grades after finals without any doubt
#
# Turkey dinner and game night monopoly the video game that should end in divorce meghanoelawrence @ Parkland, Calgary
#
# @bbum Isn’t there a wipeout VR game too? Have you tried it yet?
#
# Oh hey~ you should check out ~ my post Season 8 Drabbles ~ Heart Beat Again #Klance v similar
#
# @EASPORTSNHL @PKSubban1 @pastayoyo always beat him at the video games.
#
# So feeling great tonight. @warriors been demolished I  their home.
#
# @francisja2607 @tonya051073 @marcialynnjones @andyliverbird @AmandaAj42xx @red_half @PaddyHynan @joanne_argent @Sazzle18109229 @LeroyEdwards8 @zimmyfan66 @MattiasArvidss1 @betyzapi @Kenyankop @E82_ACPillay @SuePeace1 @jasperlfc @Mick2304mick @Rockslashjeffry Awesome Poster Frank👍Yes We Go Again &amp; We Must Keep The Momentum We've Had These Past 2 Game &amp; Stay Undefeated &amp; Not Concede Any Goals As Well My Friend👍👌Looking For JK To Rest Some Stars But Keep The Back Four &amp; Allison👌Plus He May Just Start TAA In Today Game As Well M8👍👌
#
# Warriors still gonna deal with anybody in the playoffs tho. Don’t see any team beating them 4 times in two weeks. 🤷🏾‍♂️
#
# nan
#
# 455

# %% [markdown]
# Arguably it did pretty well, certainly not all the tweets are about sports, but considering we were able to sort these into 200 topics in a few seconds, it did pretty good!
#
# ### For you
# Try adding your own key word searches into the model and re running it. Do the topics your fake tweets end up in make sense? What do you think you could do to make things a little better? Also try things like a different number of topics - how do your results chance?

# %% [markdown]
# ## Next Steps
#
# From here you've got a great baseline to start things like market research. If you find a large group of tweets relevant to either your product or business, you can use those to understand how people are discussing those issues publicly. Either from a sentiment analysis to understand how people feel, as market research to understand what people seem to need, or to discover which users to target for advertising purposes. Of course, this is a very minimal and may not be perfect for answering those questions explicitly. However, understanding this model can act as a solid basis to iterate to more complex models which may see greater success in understanding your business problems via twitter text analysis.
