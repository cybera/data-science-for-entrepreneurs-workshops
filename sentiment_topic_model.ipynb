# %% [markdown]
# # What can we learn from Twitter data?
#
# Often in data science we find ourselves asking open ended questions as part of our analysis, and a big part of finding successful results is starting with an idea - and changing your analysis once you hit a dead end based on the data, or if you think of a better way to do it. This notebook will demonstrate this process by using sentiment analysis on Twitter data, and showing how by changing our initial idea with a different methodology (in our case: topic modeling), you can find interesting results!
#
# ## Goal
# Learn about sentiment analysis and the process of iterating on an initial question you would like to answer.
#
# ## Disclaimer
# As we are working with uncensored tweets captured indiscriminately from Calgary, there is a possibility that this notebook may display content that is offensive or vulgar. These tweets do not represent the views of Cybera or its employees. This dataset is simply meant to be an activity in working with text-based data, and some possible analysis surrounding it.
#
# ## Twitter Data
# By now we have developed a familiarity with our Twitter data. At this point, we might be wondering what kind of questions we can answer or insights we can gain from this data. An exciting first choice is to ask ourselves something that we may all think of as familiar: how are we feeling today? But rather than asking _ourselves_ that question, we will extract that data from our Twitter data set. This is known as **Sentiment Analysis**.
#
#
# Notice periodic behaviour
#
# TODO: Clean plot/visualize it differently to show when the most popular tweeting hours/days are. Topic/Sentiment analysis on those days???

# %% [markdown]
# ## Load python modules
#
# Load python libraries first. Additional libraries that we are going to use in this notebook are:
#  - [gensim](https://radimrehurek.com/gensim/) -  topic modelling library

# %%
# The modules we'll need
# !pip install --upgrade pandas --user
import pandas as pd
import urllib.request
import pandas as pd 
import matplotlib.pyplot as plt
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import nltk
from IPython.display import HTML
# %matplotlib inline
nltk.download('stopwords')

# This little trick is to selectively hide code in our notebook

def hide_me():
    return HTML('''<script>
    code_show=true; 
    function code_toggle() {
        if (code_show){
            $('div.cell.code_cell.rendered.selected div.input').hide();
        } else {
            $('div.cell.code_cell.rendered.selected div.input').show();
        }
        code_show = !code_show
    } 

    $( document ).ready(code_toggle);
    </script>

    To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/78/78/50ef81a903eccc4e90e278a143c9a0530f05199f6221d2e1b21025852982/pandas-0.23.4-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (14.6MB)
#     100% |████████████████████████████████| 14.7MB 2.4MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /usr/local/lib/python3.6/site-packages (from pandas) (1.15.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/site-packages (from pandas) (2.6.1)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/site-packages (from pandas) (2018.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.10.0)
# nxviz 0.5.0 has requirement numpy==1.15.0, but you'll have numpy 1.15.4 which is incompatible.
# nxviz 0.5.0 has requirement pandas==0.23.3, but you'll have pandas 0.23.4 which is incompatible.
# nxviz 0.5.0 has requirement setuptools==40.0.0, but you'll have setuptools 39.1.0 which is incompatible.
# Installing collected packages: pandas
# Successfully installed pandas-0.23.4

# %% [markdown]
# ## Importing the Data
#
# As we've done before, we are going to import our data and adjust the time stamp. This time however, we are going to try and understand _when_ people are tweeting within Calgary.

# %%
target_url="https://swift-yeg.cloud.cybera.ca:8080/v1/AUTH_233e84cd313945c992b4b585f7b9125d/geeky-summit/tweets_cleaned.csv"
file_name="tweets_cleaned.csv"
urllib.request.urlretrieve(target_url, file_name)

df = pd.read_csv(file_name,parse_dates=['created_at_date']) 
# Convert to mountain standard time 
df.created_at_date= df.created_at_date.dt.tz_localize('UTC').dt.tz_convert('MST')

# %% [markdown]
# ## Sentiment Analysis
#
# Sentiment analysis is easy for a human to do. It's quite simple to distinguish a sentence that is positive, negative, or neutral simply by reading it. Of course, how do we get a computer to do it for us? There are in fact several ways to do this such as training a neural network to classify our data. Unfortunately, we don't have that luxury! Luckily however, there are also libraries that assign a score, positive or negative, to certain words and characters. These libraries are called **lexicons** and each lexicon will score an individual word as positive or negative, and words that aren't within the lexicon will have a score of zero.
#
# ### VADER
#
# The lexicon we will be using is called VADER (Valence Aware Dictionary and sEntiment Reasoner), and you can read more about it [here](http://comp.social.gatech.edu/papers/icwsm14.vader.hutto.pdf) and [here](https://github.com/cjhutto/vaderSentiment). However, for us VADER is the "most ideal" sentiment lexicon as it also encodes sentiment for emojis and different levels of capitalization: something that we'll likely see a lot of on Twitter. Let's take a look at what VADER does below

# %%
try:
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
except ModuleNotFoundError:
    # !pip install vaderSentiment --user
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
    print("If you see this message, please select Kernel -> Restart and run all from the top menu")
analyser = SentimentIntensityAnalyzer()

sentence = "I love eating pasta" 

print(analyser.polarity_scores(sentence))
# Out:
# {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}

# %% [markdown]
# Where VADER returns a score for negative language `neg`, a score for neutral language `neu`, a score for positive language `pos`, and a summary score `compound`. Where in this case we see that the sentence `I love eating pasta` is predominantly positive in nature.
#
# One of the nice things about VADER is that it will also assume that text in capitals is either more positive or negative. For example, if we "LOVE pasta", it is more positive that in we simply "love pasta", as seen below.

# %%
sentence = "I LOVE eating pasta" 

print(analyser.polarity_scores(sentence))
# Out:
# {'neg': 0.0, 'neu': 0.288, 'pos': 0.712, 'compound': 0.7125}

# %% [markdown]
# And if we add emojis to this, those emojis are also scored!

# %%
sentence = "I LOVE eating pasta :)" 

print(analyser.polarity_scores(sentence))
# Out:
# {'neg': 0.0, 'neu': 0.201, 'pos': 0.799, 'compound': 0.8374}

# %% [markdown]
# As well, negative sentiments behave as you'd expect

# %%
print(analyser.polarity_scores("I hate pasta"))
print(analyser.polarity_scores("I HATE pasta"))
print(analyser.polarity_scores("I HATE pasta >:("))
# Out:
# {'neg': 0.787, 'neu': 0.213, 'pos': 0.0, 'compound': -0.5719}
# {'neg': 0.816, 'neu': 0.184, 'pos': 0.0, 'compound': -0.6633}
# {'neg': 0.891, 'neu': 0.109, 'pos': 0.0, 'compound': -0.8455}

# %% [markdown]
# However, we should be aware that VADER will not recognize positive or negative words as they may appear on twitter:

# %%
print(analyser.polarity_scores("I LOVE pasta"))
print(analyser.polarity_scores("I #LOVE pasta"))
# Out:
# {'neg': 0.0, 'neu': 0.169, 'pos': 0.831, 'compound': 0.7125}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %% [markdown]
# Hence the importance of cleaning your data! That said, as hashtags can also be misleading in terms of what appears at the end of tweets, we will focus our analysis on _only_ the text bodies; we will ignore all hashtags and `@` user mentions.
#
# ### When are people Tweeting in Calgary
#
# Before we begin our sentiment analysis, it is always a good idea to understand _when_ people are tweeting as time can be an important factor in sentiment analysis (for example, before lunch or dinner one might see some "hanger" effects in the tweets!). In this case, let's take a quick look at the time distribution histogram of tweets.

# %%
ax = df['created_at_date'].groupby([
            df.created_at_date.dt.day, 
            df.created_at_date.dt.hour
    ]).count().plot(kind="bar",
                    figsize = (18,8))

ax.set_xlabel("Time (Hours)", size = 20)
ax.set_ylabel("Number of tweets", size=20)
plt.show()

# This little trick is to selectively hide code in our notebook

hide_me()
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#
#     $( document ).ready(code_toggle);
#     </script>
#
#     To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# Unsurprisingly, we see that there is a periodic behavior in terms of when tweets are... tweeted. In this case we see a daily lull starting from around 22:00 until 6:00, or the times when people are typically sleeping and not thinking about writing tweets.

# %% [markdown]
# ### Scoring the Sentiment of Twitter Data
#
# Now that we have a basic understanding of how VADER works, calculating the sentiment of all our tweets is quite straightforward. In our case, we are only interested in the compound sentiment of the tweets.

# %%
def compoundSentiment(row):
    # Notice here how we're calling explicitly the extended_tweet_cleaned
    # entry 
    score = analyser.polarity_scores(row.extended_tweet_cleaned)
    return score['compound']

# Here we use the 'apply' function to apply a function to our data frame
# axis=1 means to apply this function row-by-row

df['score'] = df.apply(compoundSentiment, axis=1)

df.head()
# Out:
#             created_at_date                           hashtags_string  \
# 0 2018-11-02 14:01:56-07:00
# 1 2018-11-02 14:02:01-07:00
# 2 2018-11-02 14:02:05-07:00  job Calgary SupplyChain Hiring CareerArc
# 3 2018-11-02 14:02:10-07:00
# 4 2018-11-02 14:02:13-07:00                               Calgary job
#
#       user_string      user_location  longitude    latitude  \
# 0         Symin16  Toronto ✈ Calgary        NaN         NaN
# 1  TwoCanSamAdams                YYC        NaN         NaN
# 2                            Calgary  51.004583 -114.007914
# 3                                 🌎📱        NaN         NaN
# 4                            Calgary  50.997882 -114.074005
#
#                    name     screen_name  \
# 0                     ♠   jessmayumba85
# 1  hannahrae cuddleslug      thimblewad
# 2  TMJ - CAL Manuf Jobs   tmj_cal_manuf
# 3             Sunny Rai      TheSunsRay
# 4   TMJ-CAL Retail Jobs  tmj_cal_retail
#
#                                       extended_tweet  \
# 0                      @Symin16 I’d like to know who
# 1  @TwoCanSamAdams Legit. There are still chunks ...
# 2  Can you recommend anyone for this #job in #Cal...
# 3                  Kids See Ghosts:  love this track
# 4  See our latest #Calgary, AB #job and click to ...
#
#                               extended_tweet_cleaned   score
# 0                               I’d like to know who  0.3612
# 1    Legit. There are still chunks in the sink an... -0.2263
# 2  Can you recommend anyone for this   in  , AB? ...  0.3612
# 3                  Kids See Ghosts:  love this track  0.6369
# 4  See our latest  , AB   and click to apply: bar...  0.0000

# %% [markdown]
# Where we'll notice on the far left of our data frame, we now have a column called `score` with all our sentiment scores from the text. One important thing to note is that if a tweet contains one or more words not contained within the lexicon for scoring, the entire sentiment score for that tweet is zero.
#
# ### Sentiment as a function of time
#
# A natural first question with this data is to ask "Does how positively or negatively people are talking change throughout the day?". This could be an interesting question for a few reasons, the most predominant being that it could be used to detect current events. If there is suddenly an influx of very positive or very negative tweets, that could indicate that there is an important event happening. Let's see how the sentiment of tweets changes per-hour in this data set. In order to do that, we have to group our data by time first, and then create a boxplot so that we may get some indication of how the data is distributed.

# %% [markdown]
# ### Brief note on box plots
#
# Boxplots are an excellent way to summarize statistical data as they readily display how the data is distributed - giving you a better idea as to the range, and more importantly, the distinguishability of your data. However if you've never seen one before, here's a few important things to note about boxplots and what everything they display means. To begin, here is a labeled boxplot
#
# ![alt-text](https://cdn-images-1.medium.com/max/800/1*2c21SkzJMf3frPXPAR_gZA.png)
#
# What we see here is a few important pieces
# 1. The 'box' itself is centered on the median of the data, and has width equal to the interquartile range, or in discrete data this box contains 50% of all points.
# 2. The lines that extend out are known as "whiskers" and extend from the bottom of the box, to a distance equal to 1.5 times the width of the box on each side (the inter quartile range)
# 3. Finally, any points outside of the whiskers are drawn individually

# %%
s_df = df.drop_duplicates(subset='extended_tweet_cleaned', keep="last").copy()
# s_df = s_df[s_df.score !=0]
s_df = s_df[s_df.created_at_date.dt.day !=9]


median = s_df[['score', 
             'created_at_date']].groupby(
                            by=[
                                s_df.created_at_date.dt.day, 
                                s_df.created_at_date.dt.hour])

ax = median.boxplot(subplots=False,
                             figsize = (19,8),
                             rot = 90,
                            )

ax.set_xlabel("Time (Hours)", size = 20)
ax.set_ylabel("Sentiment", size = 20)
plt.show()

# %% [markdown]
# Where in the plot above, we don't see a lot of variation. That's not very exciting. However, there is a reason for that! But...
#
# ### Exercise
#
# There is a way to see some more variation! Add a single line of code to the cell above to filter out some data so that we can actually see that variation.
#
# **Hint** Remember that if there are no words in the VADER lexicon within a tweet, it returns a sentiment score in `s_df['score']` as zero. How could you get remove all of those zero values?
#
#
# ### Distinguishability of data
#
# Once you've filtered the tweets down appropriately to see some minor variations within the data, you may notice what look like interesting variations in the size of the boxes! Unfortunately however, we also have to keep in mind our _time distribution_ that we created earlier. In almost all cases, our significantly different sentiment takes place during times where we have scored significantly fewer tweets - our results are biased due to a lack of data.
#
# Not to worry however! This is not unexpected. As we've aggregated about 14,000 tweets from Calgary over a few days, we're simply seeing aggregate scores about how people are writing about numerous topics every day. Which brings us to an interesting question: Can we isolate those topics, and how do people feel about them?

# %% [markdown]
# ## Topic Analysis
#
# Topic analysis is an exciting technique that allows you to cluster documents/sentences or in our case, tweets, into groups of text around a similar topic as well as calculate key words in that topic. There are numerous algorithms and methods  for this task, however what we'll focus on is Latent Dirichlet Allocation (LDA). The name is a result of inferring the topics (Latent) from a multi-variate Dirichlet distribution, and they are allocated (sorted) from that distribution. That's a lot to digest, and _understanding_ how it works in general is not required in order to _use_ LDA analysis. That said, understanding it will certainly make any models more effective!
#
#
# ### Important Note
#
# While topic modeling and analysis is important, a topic model will never actually tell you what each topic is about. All your model will do is cluster each document into labeled topics, that you: a human, will then have to understand what the topic actually is about.
#
# ### Definitions
#
# ##### Corpus
# A corpus refers to all the unique words contained in your text. In our case, this corpus consists of all the words within our tweets.
#
# ##### Word Vectors
#
# A word vector is the conversion of a word into a sparse 'one-hot' vector. What this means is that each word contained within all your texts is mapped to a unique vector. For example, the word "karate" may appear as
#
# \begin{equation}
# \mbox{Karate} =
# \begin{pmatrix}
# 0 \\
# \vdots \\
# 1 \\
# \vdots \\
# 0
# \end{pmatrix}
# \end{equation}
#
# Where it is represented as a _unique_ and _sparse_ vector that contains a single non-zero entry. The size of each word vector is the same, and is the size of our corpus.
#
# ##### Document Vectors
#
# A document vector is simply the word vector representation of a document/sentence or in our case, a tweet. For example, the sentence
# ```
# wax on, wax off
# ```
#
# is simply the vector sum of our word vectors for each word
# \begin{equation}
# \vec{D}_1 = \vec{w}_1 + \vec{w}_2 + \vec{w}_1 + \vec{w_3}
# \end{equation}
#
#
# ##### Corpus (round two)
#
# Now that we've defined word and document vectors, our corpus is defined as our entire set of documents, or
#
# \begin{equation}
# C = \{\vec{D}_1, \vec{D}_2, ..., \vec{D}_N\}
# \end{equation}
# where $N$ is the total number of documents, in our case the total number of tweets.
#
#
# # LDA
#
# LDA analysis consists of sampling many distributions of topics, documents, and words from the corpus to apply Bayesian methods to create word and document distributions within topics.
#
# ### How it works
#
# 1. At a high level, the first step of LDA analysis is to create a distribution of words for each document in our corpus. Once this is done
#
# 2. Once the word distribution for each document is defined, each word in the _corpus_ is _randomly_ assigned to one of your pre-determined number of topics. This defines both our distributions of words in a topic, as well as our distributions of topics in a document.
#
# 3. Once we've set that up, we start looping through words in our corpus and complete the following steps through some number of iterations (preferably until your distributions converge... but as with any Bayesian method we can never _really_ be sure if it has!)
#
#    a. Sample a word from a document and remove it from its current topic distribution
#
#    b. Sample using the document's topic distribution, and the topics word distribution to decide which topic this word now belongs to.
#
#    c. Repeat the above two steps for all words in each document the corpus
#
#
# There are a few other technical such as how to chose parameters of the Dirichlet distributions or optimization of the sampling, how many times to iterate, but at the highest level, this is the basic process LDA completes.
#
# After LDA has completed this process several times, one should have a well defined distribution of _words_ in each _topic_. Using the distribution of words in each topic and the word distribution of each document, it is possible to define a _topic distribution_ in every document. Meaning that every document can be represented by a distribution of topics. Using this topic distribution, it is possible to calculate similarities between documents, or in our case, discover the _dominant_ (most probable) topic of a document.

# %% [markdown]
# ## The Analysis
#
# Due to the nature of Twitter, and the likelihood of there being _many_ topics that are different from day to day, it's convenient to focus on a single day, in our case we have chosen Tuesday. Below we simply create a new data frame that just contains the Tuesday data

# %%
subset = df[df.created_at_date.dt.day ==3]
# Road incident and dead animal clean up reporting, remove it for the
# sake of speeding up any topic modeling. Feel free to put this back in if you'd like
subset = subset[subset.screen_name != '311calgary'] 
subset = subset.reset_index()
print("Total tweets =", len(subset))
subset.head()
# Out:
# Total tweets = 3592
#    index           created_at_date   hashtags_string  \
# 0   1580 2018-11-03 00:00:10-07:00
# 1   1581 2018-11-03 00:01:18-07:00             ableg
# 2   1582 2018-11-03 00:02:26-07:00
# 3   1583 2018-11-03 00:02:51-07:00
# 4   1584 2018-11-03 00:05:13-07:00  ATPZORRO LOVEYYC
#
#                              user_string           user_location  longitude  \
# 0                        LFCTransferRoom                  Canada        NaN
# 1                          realmarkwells                 Calgary        NaN
# 2  GoaleeMurph kasim_a29 GalvanisdHockey     Calgary, AB, Canada        NaN
# 3                                         Calgary Alberta Canada     51.045
# 4                                ATPlive             Calgary, AB        NaN
#
#    latitude                name     screen_name  \
# 0       NaN  Captain Fantastic8      nattyroons
# 1       NaN       Jeff Callaway    JeffCallaway
# 2       NaN       FHumpires.com       fhumpires
# 3  -114.057       Jennifer Park  naturaliconyyc
# 4       NaN          Alex Wihak       WihakAlex
#
#                                       extended_tweet  \
# 0       @LFCTransferRoom So what was Shaqiri's time🤔
# 1               @realmarkwells NDP posturing #ableg
# 2  @GoaleeMurph @kasim_a29 @GalvanisdHockey Glad ...
# 3  Sun worship💜💜💜. November is upon us. Not my fa...
# 4  @ATPlive I know it’s not a meme but how I feel...
#
#                               extended_tweet_cleaned   score
# 0                        So what was Shaqiri's time🤔  0.0000
# 1                                   NDP posturing     0.0000
# 2        Glad I specified which keeper then witho...  0.4588
# 3  Sun worship💜💜💜. November is upon us. Not my fa... -0.3412
# 4    I know it’s not a meme but how I feel someti...  0.0000

# %% [markdown]
# Where we're now going to be dealing with approximately 3,600 tweets in total to run our topic model.
#
# ## Tokenizing the Corpus
# However, we're not ready to start topic modeling yet! We have to clean these tweets up even more and do some processing first, as the "cleaner" our corpus is before analysis, our topic model will have an easier time We have to first turn our tweets into tokens, which take the sentence, remove punctuation, and converts it to a list. As an example, let's see the results of tokenizing the sentence below.

# %%
sentence = "I certainly, absolutely, positively, LOVE! text processing? And the number 10"
print("tokenized sentence:", gensim.utils.simple_preprocess(sentence, min_len=3))
# Out:
# tokenized sentence: ['certainly', 'absolutely', 'positively', 'love', 'text', 'processing', 'and', 'the', 'number']

# %% [markdown]
# Where all the punctuation, numbers, as well as words with fewer than three characters have been removed. We've removed punctuation as it doesn't (typically) do much in terms of the _topic_ or _context_ of a sentence.  We've also removed words of shorter than three characters as they also typically don't add anything particularly meaningful, and tend to just "clutter up" our corpus - this makes it harder to teach the computer how to understand the topics!
#
# After tokenization, a way to shorten your corpus is to remove superfluous conjugation of words, in our case _all_ conjugation. The idea being that conjugation certainly makes text easier to read, the differences in _meaning_ between differently conjugated words is minimal. In this case, we will use a process known as stemming which reduces words back to their root word. Let's see how that looks using the tokens we made above.

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

tokens = gensim.utils.simple_preprocess(sentence, min_len=3)
for word in tokens:
    print(stemmer.stem(word))
# Out:
# certainli
# absolut
# posit
# love
# text
# process
# and
# the
# number

# %% [markdown]
# Notice how the "end" of some words has been truncated and occasionally replaced with `i` or nothing. This allows us to reduce the size of our corpus (the total number of all the words we're working with) by reducing all possible conjugations to a single word. This will both speed up our model, and (potentially) help with the topic analysis.
#
# Finally, we will remove all stop words from the corpus, as well as add the word "amp" to stop words (as it represents an ampersand as we discovered). Below we see a list of some of the stop words that we will be removing from our corpus.

# %%
stop_words = nltk.corpus.stopwords.words('english')
stop_words.append('amp')
print(stop_words[1:10])
stop_words = set(stop_words)
# Out:
# ['me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %% [markdown]
# When it comes to any text analysis or topic modeling, the most important step is always cleaning your text to reduce the number of words your model needs to learn. The purpose of cleaning all this text is best summarized by Kevin from The Office:
#
# ![kevin](https://media.giphy.com/media/xIZku8V0y7uqk/giphy.gif)
#
# While we've removed a lot of what we would typically consider to be "language" from the text, it still does the trick!
#
# ## Cleaning the text in our DataFrame
# We will now tokenize, stem, and remove stop words from all our texts as seen below. We note that stemming is technically optional, but we have gone through the complete process here.

# %%
# Clean and tokenize 
def sent_to_words(row):
    sentence = row.extended_tweet_cleaned
    return(gensim.utils.simple_preprocess(sentence,min_len=3))  

# Create a new "tokens" colmn with our sent_to_words function
subset['tokens'] = subset.apply(sent_to_words, axis=1)

# %%
# Function for stemming 
def stem(word):
    return stemmer.stem(word)

# Wrapper function to clean all the text at once 
def tokens_to_lda(row):
    data_token = row.tokens
    tokens = [token for token in data_token if token not in stop_words]
    # Always stem last as your stop words will look different if you stem first!
    tokens = [stem(token) for token in tokens]
    return tokens

# Now we create a 'lemma' column for our super cleaned data!
subset['lemma'] = subset.apply(tokens_to_lda, axis=1)

# We are also removing all data where the tweet is less than four words long. 
subset = subset[subset['lemma'].apply(lambda x: len(x) > 3)]

print("Total Tweets to analyze after cleaning: ", len(subset))
subset.head(3)
# Out:
# Total Tweets to analyze after cleaning:  2595
#    index           created_at_date   hashtags_string  \
# 2   1582 2018-11-03 00:02:26-07:00
# 3   1583 2018-11-03 00:02:51-07:00
# 4   1584 2018-11-03 00:05:13-07:00  ATPZORRO LOVEYYC
#
#                              user_string           user_location  longitude  \
# 2  GoaleeMurph kasim_a29 GalvanisdHockey     Calgary, AB, Canada        NaN
# 3                                         Calgary Alberta Canada     51.045
# 4                                ATPlive             Calgary, AB        NaN
#
#    latitude           name     screen_name  \
# 2       NaN  FHumpires.com       fhumpires
# 3  -114.057  Jennifer Park  naturaliconyyc
# 4       NaN     Alex Wihak       WihakAlex
#
#                                       extended_tweet  \
# 2  @GoaleeMurph @kasim_a29 @GalvanisdHockey Glad ...
# 3  Sun worship💜💜💜. November is upon us. Not my fa...
# 4  @ATPlive I know it’s not a meme but how I feel...
#
#                               extended_tweet_cleaned   score  \
# 2        Glad I specified which keeper then witho...  0.4588
# 3  Sun worship💜💜💜. November is upon us. Not my fa... -0.3412
# 4    I know it’s not a meme but how I feel someti...  0.0000
#
#                                               tokens  \
# 2  [glad, specified, which, keeper, then, without...
# 3  [sun, worship, november, upon, not, fave, mont...
# 4  [know, not, meme, but, how, feel, sometimes, f...
#
#                                                lemma
# 2  [glad, specifi, keeper, without, refer, dimens...
# 3  [sun, worship, novemb, upon, fave, month, scro...
# 4                [know, meme, feel, sometim, father]

# %% [markdown]
# ### Final Preparations For LDA
#
# Finally, we need to prepare our dictionary as well and a corpus for our LDA routines. In our case we will be using  `gensim` text mining module, which is opensource with documentation [here](https://radimrehurek.com/gensim/index.html). Our first step is to use their pre-packaged routines to create our word and document vectors which is done below.

# %%
# Prep for the corpus 
dictionary = corpora.Dictionary(subset['lemma'])
corpus = [dictionary.doc2bow(text) for text in subset['lemma']]

print(list(dictionary)[1:10])
print(list(corpus)[2000])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [(58, 1), (131, 1), (211, 1), (804, 1), (936, 1), (1107, 1), (1314, 1), (1317, 1), (1319, 1), (1479, 1), (1776, 1)]

# %% [markdown]
# In the above output, the first list from dictionary is simply the "word vectors" or: where the non zero term in our encoding is. The second list contains two things, the word vector and the second number is how many times that words appears in the document (tweet). Our documents are indexed by the order it sees our tweet, so in the case printed above the list
# ```
# [(58, 1), (131, 1), (211, 1), (804, 1), (936, 1), (1107, 1), (1314, 1), (1317, 1), (1319, 1), (1479, 1), (1776, 1)
# ```
# is the word vector representation of the tweet in the 2000th position, or the following tokens and tweet

# %%
print("Tokens: ", subset['lemma'][2000])
print("Original Tweet:", subset['extended_tweet'][2000])
# Out:
# Tokens:  ['enter', 'chanc', 'win', 'win', 'ticket', 'fleetwood', 'mac', 'calgari']
# Original Tweet: Enter for a chance to win Win 2 Tickets To Fleetwood Mac In Calgary! at

# %% [markdown]
# We will also be using an optimized version of LDA called [MALLET](http://mallet.cs.umass.edu/). However we have to download and extract the executables, which is done below. We note that this will download to your hub account, and not your local machine.

# %%
# This is to download the binaries of the LDA package we will use. This only downloads them 
# onto the hub, and not to your local machine 
import os
import requests, zipfile, io
if not os.path.isdir("mallet-2.0.8"):
    r = requests.get('http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip')
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall()
else:
    print("Directory exists, no need to download it again.")
# Out:
# Directory exists, no need to download it again.

# %% [markdown]
# ### Digression: Choosing The Number of Topics
#
# Finally, there's the matter of deciding on how many topics we should be looking for. One of the most consistent ways to do this is by calculating the "coherence" of the topic model. The coherence of a topic model compares the similarity of the top $N$ words from each topic, which is typically done by taking the dot product of properly normalized word _embeddings_
#
# \begin{equation}
# \hat{w}_m \cdot \hat{w}_n = [-1, 1]
# \end{equation}
#
# Where the hats on each word vector is to specify that these are _not_ the one-hot-encoded vectors we saw above, but instead these word vectors are better called "word embeddings" or the results of training a neural network on some text to discover word similarities. An inner product of zero would imply the words have no similarities, an inner product close to one is contextually similar words (synonyms), and a inner product close to -1 implies contextually opposite words (antonyms).
#
# The coherence score is then calculated by some measure of the average of similarity between the top $N$ words in the each topic of the model. A higher coherence typically means a better topic model.
#
# With that in mind, what we end up doing is running the LDA analysis for several different topic models with a different number of topics. Once we've created our models and see which topic number has the highest coherence before the coherence score stagnates, or decreases. For example, this is the result of running the two code cells below (**NOTE**: If you do this yourself, you may find that your coherence graph looks considerably different! That's expected - part of LDA involves a lot of randomization and you shouldn't expect identical results between runs!)
#
# ![alt text](coherence.png)
#
#
# Where in this case the best number of topics to pick would be between 60 and 70.
#
# Unfortunately, this part of the analysis is very slow and we have run these next steps in advance and provided files for you. That said, the code that generated them is below for your interest. You're free to run these cells, but they may take quite a while to complete. That said, running the next two cells is _not_ necessary to follow the remainder of this notebook
#
# ##### NOTE
# If you wish to run the next three cells, you'll need to "uncomment" them by highlighting all the text and pressing `CMND + /` on mac/linux or `Ctrl + /` on windows.

# %%
# def coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
#     # path the the methdod we will be using for LDA analysis 
#     mallet_path = '/mallet-2.0.8/bin/mallet'
#     coherence_values = []
#     model_list = []
#     for num_topics in range(start, limit, step):
#         model = gensim.models.ldamodel.LdaModel(
#                                        corpus=corpus, 
#                                        num_topics=num_topics, 
#                                        id2word=dictionary) 
#         model_list.append(model)
#         coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
#         coherence_values.append(coherencemodel.get_coherence())

#     return model_list, coherence_values

hide_me()
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#
#     $( document ).ready(code_toggle);
#     </script>
#
#     To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.

# %%
# Can take a long time to run.
# limit=90
# start=30
# step=10

# model_list, coherence_values = coherence_values(dictionary=dictionary,
#                                                         corpus=corpus, 
#                                                         texts=subset['lemma'],
#                                                         start=start,
#                                                         limit=limit, 
#                                                         step=step)



# plt.figure(figsize = (6,3))
# x = range(start, limit, step)
# plt.plot(x, coherence_values)
# plt.xlabel("Number of  Topics", size=16)
# plt.ylabel("Coherence score", size=16)
# plt.savefig('coherence.png', bbox_inches='tight')

hide_me()
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#
#     $( document ).ready(code_toggle);
#     </script>
#
#     To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.

# %%
# # This is the function that will allow us to associate a given tweet with a topic!

# def format_topics_sentences(ldamodel=model_list[len(model_list)-1], 
#                             corpus=corpus, 
#                             texts=subset['extended_tweet'],
#                             score=subset.score):
#     # Init output
#     df = pd.DataFrame()
#     # Get main topic in each document
#     for i, row in enumerate(ldamodel[corpus]):
#         # Here we grab a list of topics, and their contributions to the model
#         topics = sorted(row, key=lambda x: (x[1]), reverse=True)
        
#         # Here we're grabbing the most dominant topic, the first index of our  row
#         # topic_num is the dominant topic number, and topic_prop is the proportion
#         # of that topic in the tweet. (Low numbers are OK)
        
#         topic_num, topic_prop = topics[0] 
        
#         # Gather words important to the topic
#         wp = ldamodel.show_topic(topic_num) 
        
#         keywords = ", ".join([word for word, prop in wp])
#         # Save them to our data frame
#         df = df.append(pd.Series([int(topic_num), 
#                                   round(topic_prop ,4), 
#                                   keywords]), 
#                                   ignore_index=True)

#     df.columns = ['topic', 'percent', 'keywords']

#     # Add original text and sentiment to the data frame 
#     contents = pd.Series(texts)
#     score = pd.Series(score)
#     df = pd.concat([df, contents, score],axis=1)
    
    
#     return(df)


# df_topic_sents_keywords = format_topics_sentences(ldamodel=model_list[3], 
#                                                   corpus=corpus, 
#                                                   texts=subset['extended_tweet'].values.tolist(),
#                                                   score=subset.reset_index().score)

# # Format
# df_dominant_topic = df_topic_sents_keywords.reset_index()
# df_dominant_topic.columns = ['number', 'topic', 'percent', 'keywords', 'tweet', 'score']

# # Show
# df_dominant_topic.head(10)

hide_me()
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#
#     $( document ).ready(code_toggle);
#     </script>
#
#     To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# ## Downloading Pre-Chosen Models
#
# Here we will download two models, one where we went through only 200 resampling iterations, and another where we went through 5000 resampling iterations. These take some time to run, so we have pre-saved the data and we will download it to a DataFrame here.

# %%
iterations_200 = pd.read_csv("https://swift-yeg.cloud.cybera.ca:8080/v1/AUTH_233e84cd313945c992b4b585f7b9125d/geeky-summit/stemmed_example.csv")
iterations_5000 = pd.read_csv('https://swift-yeg.cloud.cybera.ca:8080/v1/AUTH_233e84cd313945c992b4b585f7b9125d/geeky-summit/5000_iterations.csv')

# %% [markdown]
# # Understanding The Results
#
# Before we continue, let's take a look at what we have in the `iterations_200` data frame

# %%
iterations_200.drop_duplicates(subset='topic').head()
# Out:
#    Unnamed: 0  number  topic  percent  \
# 0           0       0   27.0   0.0374
# 1           1       1   36.0   0.0412
# 2           2       2   23.0   0.0360
# 3           3       3   42.0   0.0354
# 5           5       5   37.0   0.0749
#
#                                             keywords  \
# 0  today, place, seat, hockey, special, row, toge...
# 1  photo, anyon, post, head, made, recommend, man...
# 2  anoth, yeah, secur, bad, creat, tonight, budge...
# 3  goal, minut, shot, video, period, score, half,...
# 5  realli, idea, school, record, listen, super, s...
#
#                                                tweet   score
# 0  @GoaleeMurph @kasim_a29 @GalvanisdHockey Glad ...  0.4588
# 1  Sun worship💜💜💜. November is upon us. Not my fa... -0.3412
# 2  @ATPlive I know it’s not a meme but how I feel...  0.0000
# 3  This video by Creationist Cat is fucking aweso...  0.7346
# 5  @MMFlint Sorry Michael, but there were four me...  0.9009

# %% [markdown]
# Here we may notice that there is a few duplicate columns, but that's okay! We won't be using those anyways. The `topic` column is the topic that the tweet has been assigned to, `keywords` are the ten most important words to a given topic and are very good to help us decide what a topic is about,  `percent` is the (decimal) percent of the tweet that that falls into a particular topic. A higher decimal percent implies that the tweet is more likely to be a part of a topic. A percent of
#
# $$ \frac{1}{70} = 0.014 $$
#
# Would imply that the document is _uniformly_ distributed through all 70 topics. So, let's compare how our two models did by calculating some summary statistics

# %%
print("200 Iterations median:", 
      iterations_200['percent'].median(),
      ";+", 
      iterations_200['percent'].quantile(.90),
     ";-",
      iterations_200['percent'].quantile(.10))
print("5000 Iterations median:", 
      iterations_5000['percent'].median(),
      ";+", 
      iterations_5000['percent'].quantile(.90),
     ";-",
      iterations_5000['percent'].quantile(.10))
# Out:
# 200 Iterations median: 0.0443 ;+ 0.08035999999999999 ;- 0.0319
# 5000 Iterations median: 0.1104 ;+ 0.23087999999999997 ;- 0.0629

# %% [markdown]
# Objectively speaking, it seems the 5000 iterations model is better, but due to the the high variance of the model, it's in fact hard to tell _which_ is superior from this summary. Let's take a look at how the topics are distributed and what tweets fall within each topic.

# %% [markdown]
# ## Topic distributions
#
# The first thing we should check is to compare how topics are distributed between the two models. To do this, we will create a histogram of how many tweets appear in each topic for both the stemmed and unstemmed models

# %%
ax = iterations_200.groupby('topic')['score'].count().plot(kind='bar', figsize=(16,5))
ax.set_xlabel("Topic", size =16)
ax.set_ylabel("Count", size = 16) 
ax.set_title("200 Sampling Iterations", size =20)
ax.set_ylim(0,160)
plt.show()
ax2 = iterations_5000.groupby('topic')['score'].count().plot(kind='bar', figsize=(16,5))
ax2.set_xlabel("Topic", size =16)
ax2.set_ylabel("Count", size = 16) 
ax2.set_title("5000 Sampling Iterations", size =20)
ax2.set_ylim(0,160)
plt.show()
hide_me()
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#
#     $( document ).ready(code_toggle);
#     </script>
#
#     To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# This is starting to get exciting! We see that our two models have different topic distributions, but what's exciting is that our tweets are (somewhat) equally distributed - at least more so than they were in the time series. This means that our boxplot of sentiments may have more interesting results! In this case, let's create box plots of the sentiment of each topic and see if we can find any interesting results based on how positively or negatively people are tweeting about a topic. Of course, as with before, we'll have to keep the histogram in mind when comparing box plots.

# %%
ax = iterations_200[iterations_200.score !=0].boxplot(figsize = (16,6), column=['score'], by='topic', rot=90)

# Weird off by one error, need to move the mean over. 
def shift(df):
    df.topic +=1
    return df

plot_df = iterations_200[iterations_200.score !=0].groupby('topic').mean().reset_index().apply(shift, axis=1).copy()

plot_df.plot(kind='line', 
            rot=90,
            y = 'score',
            ax = ax,
            x = 'topic',
            label ='mean')
ax.set_xlabel("Topic", size = 16)
ax.set_ylabel("Sentiment", size = 16)
ax.set_title("200 Sampling Iterations", size = 20)
plt.show()

ax2 = iterations_5000[iterations_5000.score !=0].boxplot(figsize = (16,6), column=['score'], by='topic', rot=90)

plot_df = iterations_5000[iterations_5000.score !=0].groupby('topic').mean().reset_index().apply(shift, axis=1).copy()

plot_df.plot(kind='line', 
            rot=90,
            y = 'score',
            ax = ax2,
            x = 'topic', label ='mean')
ax2.set_xlabel("Topic", size = 16)
ax2.set_ylabel("Sentiment", size = 16)
ax2.set_title("5000 Sampling Iterations", size = 20)
plt.show()

hide_me()
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#
#     $( document ).ready(code_toggle);
#     </script>
#
#     To show/hide the above code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# In the plots above, we have not added tweets in each topic with a sentiment of zero. But at last! Some interesting results! With our histogram from the previous graphs in mind, we see that we now have some sentiments that are not only  _distinguishable_ but we also have it in terms of different topics. For example, consider topics 29 and 31 in the boxplot with 5000 iterations. As both these boxes contain a similar number of points, we can be confident that the sentiment expressed in these two topics will be different.  With this data, we can understand how people feel about specific topics. Certainly, some topics will be more "coherent" than others.

# %% [markdown]
# ### Explore The Data
#
# Below we've set up a comparison between two topics that can loosely be defined as hockey. Consider how the two models compare. As well, look for outliers in the above box plots and see what each topic is about. For example is there a box with a very small spread in data points? What are people positive or negative about? A box with a very large spread in data points? What are people so polarized about? Does the sentiment scores surrounding a given topic make sense? To get you started below, we've set up two topics about hockey/sports for you to explore and contrast, but feel free to explore different topics in each model by changing the topic in `print_df` below.

# %%
print_df = iterations_200[iterations_200.topic == 0].sort_values(by='percent', ascending = False).copy()
for index, text in enumerate(print_df.tweet):
    print(text, print_df.percent.iloc[index])
    print()
    print(print_df.keywords.iloc[index])
    print()
    print("*" * 60)
# Out:
# Two of the best play by play announcers in Canadian broadcasting history going head to head tonight with Bob Cole calling @NHLFlames game vs #Hawks on @hockeynight and @CCtsn calling @calstampeders game against #Lions @cbcsports Pleasure to watch both of them in action, 0.1005
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
#
.034
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Wow .. Kutcherov on the PP is a demon. 1-1 game now.  #Habs 0.034
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Dube will score #Flames1stGoal tonight vs. Chicago. 0.034
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Armia .. Wow... #Habs could easily be up 4-0 in this game. #Habs 0.034
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @journo_dale @PMLaurier All due respect, we need to start calling #torybullshit what it is. #ToryBullshit 0.034
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @gbobke @geoff_perry @JustinTrudeau @iqrakhalid @HonAhmedHussen When they find her they will kill her. Religion of Peace in action... 0.0333
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# What a fucking pass What a finish Tie game  0.0333
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Cheering on our boys from home tonight. Let’s FIRE. IT. UP!!🔥 @calstampeders #GoStampsGo #CFLgameday #CFLCommunity #yyc  0.0333
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @BWildeGlobal @Global_Montreal I did read it. I just don't agree that the TB goalie stole the game. 0.0333
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# What time is our game today..My LFC Family😎  0.0333
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Score is 3-2 after 2 periods for Chicago. Close game so far.   #GoFlames  0.0333
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Glad to hear you are still keeping up with the best game in the world @MarcyGrossman  Even from beautiful #Dubai 0.0327
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @JohnJHarwood I’m not a fan of either team. But that was an awesome game.  Congrats to both for giving it all . . . 0.0327
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @jememorris One more touchdown and say goodnight Bo. Starting to look like a #CFL pre-season game. 0.0327
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @CWGC @GWar100 A very thoughtful tribute to our casualties. Sent my recordings for Jorgen and Erick Groseth. 0.0322
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# All of these voters in have not provinces will do the jig for more free money except it’s a shell game 0.0322
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @TheSportsJim Lawl no Mike Smith is tonight 0.0319
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @crystalhoff Should I watch tonight or keep watching Sabrina?? 0.0319
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Hear from Grindstone GM @domdirocco on what is happening in Calgary this weekend with the @infernocwhl to help grow the female game!   #grindstoneaward #girlshockey #charity #changemakers…  0.0316
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Going to see Birds of Chicago tonight courtesy of @SceneYYC Thanks a heap! @calgaryfolkfest @jtandalli #livemusic #yyc 0.0313
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Live #UFC 230 Tonight @PigandDuke on 12th No Cover Heavyweight Title #RealPub  0.0313
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @GregOnSports Good news though, he didn’t retire after signing with them. 0.0298
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# Don't tell me you're told old to like The White Stripes. 0.0288
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @fiascogelato @d_vargas @BandedPeak_Brew Sounds like a perfect day! ❤️ 0.0262
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************
# @k_kfrock @MartinBait @albertaseparate You know they do move around right. They are everywhere, you just didn't see them. 0.0251
#
# game, tonight, move, action, calling, remember, blackhawks, cookie, stream, party
#
# ************************************************************

# %%
print_df = iterations_5000[iterations_5000.topic == 26].sort_values(by='percent', ascending = False).copy()
for index, text in enumerate(print_df.tweet):
    print(text, print_df.percent.iloc[index])
    print()
    print(print_df.keywords.iloc[index])
    print()
    print("*" * 60)
# Out:
# Two of the best play by play announcers in Canadian broadcasting history going head to head tonight with Bob Cole calling @NHLFlames game vs #Hawks on @hockeynight and @CCtsn calling @calstampeders game against #Lions @cbcsports Pleasure to watch both of them in action, 0.3924
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Good news  for the Blazers in the early game as Okotoks beats Wainwright....we will look for a slide rule to figure out the combinations and permutations.... 0.2475
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Blazers player of the game 7 - Action Jackson..... 0.2466
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @ManUtd A good win in the end for MU but another inconsistent performance. To get back into the top four or challenge for any trophy, players (starters and subs) need to be consistent for 90mins/every match for the entire season. One-off performances do not win anything! 0.2213
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
#
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# The best seat I've ever had for @NHLFlames game...  Wow.  #hockeynight #GameOn #Flames  0.0774
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# ...and after a short ringing hiatus, play resumes! 0.0754
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @Rory_Johnston @ianbremmer If you’re going to score it like a fight, I want rounds and punches thrown/punches landed metrics. 0.0752
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# All of these voters in have not provinces will do the jig for more free money except it’s a shell game 0.0737
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @Obey_Kiwiz @YouTube I can be him maybe I’m already him friend me in FORTNITE I’m a iPhone player I can do a built fight user:LOLGamer405 0.0737
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# #Habs stuck in their own zone forever .. 4-1 game now :( 0.0736
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @Aferinx ITS LIKE A GACHA GAME WITH A ENTRANCE FEE 0.0736
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Sounded like Andre was arguing with the fans 😆😆😆 0.0736
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Armia .. Wow... #Habs could easily be up 4-0 in this game. #Habs 0.0736
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @joeyalfieri Why .. are they planning to play 3 QBs next yr?  :) 0.0717
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Thankful #Slaughter doesn’t forget about Canadian fans! #centurycasino #Edmonton #MarkSlaughter  #Winnipeg is next!  0.0717
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @NikkF07 At that point it's like "why even have a regular season"? 0.0717
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# There wasn’t nearly enough David S. Pumpkins this Halloween season. 0.0702
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Browne gets hammered from behind.  Blazers somehow short handed now... 0.0702
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# My very early prediction is that Max is toast, as is his party. 0.0702
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Once I figure out how not to be exhausted going up and down ramps, get squished by the elevator, all while getting dropped off almost 2 blocks away I'm sure I…  0.069
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Hey @Skier_one  you are definitely a @TheGreatTrail Champion...... for all seasons! 0.0682
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Thinking about a quick trip to London UK at the beginning of Feb. I bet the weather sucks at that time. 0.0679
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @RearAdBsBlog @Rod_Gallant @spittinchiclets The douche strikes again. So much talent, his antics are a detriment to the game 0.0671
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @dan_abramov Unfortunately this doesn’t seem to be available on mobile yet. 0.066
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @StuCowan1 .. and Drouin... dude should be stapled to the bench, IMO. 0.065
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @lesleychestrman @EmilyRNunn Now you have my curiosity going. I just made a note to look for this stuff the next time I do groceries. If it's cheap, I'll get a box and let you know how it goes! 🤣 0.0635
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Quick goalie change for the Blazers 0.0628
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# This is how to call out a weasel. Well done. 0.0575
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# THORHAUG with the shorty to put the @OilersMAA up 5-4 with 7:27 to go in 3rd 1:15 left in penalty assist to @jackson_vyse 0.0572
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @joshbillzz I used to convert to Naira before when I first got here 😂😂it made things look so expensive 0.0546
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @RobMeekel @JustinTrudeau I think he’s playing cowboy somewhere in BC 0.0546
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @DarrenWHaynes The goaltenders need to play much better and we won’t have to come from behind. 0.0515
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# @k_kfrock @MartinBait @albertaseparate You have zero clues about homelessness in any province so knock off the bullshit. 0.0495
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************
# Nothing unites a league in joy then a PR signing. 0.0443
#
# game, play, tonight, season, minut, head, win, fan, penalti, player
#
# ************************************************************

# %% [markdown]
# # Conclusion
#
# Using the data above, we could start to understand how Twitter users in Calgary feel about individual topics.
#
# We've  also given a practical introduction to LDA analysis and sentiment analysis with python. More importantly however, we've demonstrated how you can extract interesting results when the initial data analysis didn't show anything promising. In our case, our initial time series and sentiment didn't really reveal anything fascinating, and we needed to do something more exciting in order to glean useful information from our twitter data. And at the end of the day, that's what Data Science is all about - being creative in order to extract meaningful information where it may not have been initially obvious.
